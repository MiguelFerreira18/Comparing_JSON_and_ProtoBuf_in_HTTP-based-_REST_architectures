# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display,Markdown
from scipy.stats import (
    shapiro,
    levene,
    ttest_ind,
    mannwhitneyu,
    normaltest,
    median_test,
    kruskal,
    t,
)
from cliffs_delta import cliffs_delta
import constants_pynb_1000_gateway as const
from collections import Counter

# %%
metric_selection = [const.METRIC_NAME, const.TIMESTAP, const.METRIC_VALUE]
metric_row_selection = [
    const.DATA_SENT,
    const.DATA_RECEIVED,
    const.RESPONSE_SIZE,
    const.REPONSE_SIZE,
    const.RESPONSE_TIME,
    const.HTTP_REQ_DURATION,
]
metric_selection_pods = [const.TOTAL]

# %% [markdown]
# # Load All Reports

# %%
# Create User
## Normal Report
json_create_user_1 = pd.read_csv(
    const.JSON_CREATE_USER_1, usecols=metric_selection
)
json_create_user_1 = json_create_user_1[
    json_create_user_1[const.METRIC_NAME].isin(metric_row_selection)
]

json_create_user_2 = pd.read_csv(
    const.JSON_CREATE_USER_2, usecols=metric_selection
)
json_create_user_2 = json_create_user_2[
    json_create_user_2[const.METRIC_NAME].isin(metric_row_selection)
]

json_create_user_3 = pd.read_csv(
    const.JSON_CREATE_USER_3, usecols=metric_selection
)
json_create_user_3 = json_create_user_3[
    json_create_user_3[const.METRIC_NAME].isin(metric_row_selection)
]

## Pod Report
json_create_user_pod_1 = pd.read_csv(
    const.JSON_CREATE_USER_POD_1, usecols=metric_selection_pods
)
json_create_user_pod_2 = pd.read_csv(
    const.JSON_CREATE_USER_POD_2, usecols=metric_selection_pods
)
json_create_user_pod_3 = pd.read_csv(
    const.JSON_CREATE_USER_POD_3, usecols=metric_selection_pods
)
## Gateway Pod Report
json_create_user_gateway_pod_1 = pd.read_csv(
    const.JSON_CREATE_USER_POD_GATEWAY_1, usecols=metric_selection_pods
)
json_create_user_gateway_pod_2 = pd.read_csv(
    const.JSON_CREATE_USER_POD_GATEWAY_2, usecols=metric_selection_pods
)
json_create_user_gateway_pod_3 = pd.read_csv(
    const.JSON_CREATE_USER_POD_GATEWAY_3, usecols=metric_selection_pods
)

# Get all Users
## Normal Report
json_get_all_users_1 = pd.read_csv(
    const.JSON_GET_ALL_USERS_1, usecols=metric_selection
)
json_get_all_users_1 = json_get_all_users_1[
    json_get_all_users_1[const.METRIC_NAME].isin(metric_row_selection)
]

json_get_all_users_2 = pd.read_csv(
    const.JSON_GET_ALL_USERS_2, usecols=metric_selection
)
json_get_all_users_2 = json_get_all_users_2[
    json_get_all_users_2[const.METRIC_NAME].isin(metric_row_selection)
]

json_get_all_users_3 = pd.read_csv(
    const.JSON_GET_ALL_USERS_3, usecols=metric_selection
)
json_get_all_users_3 = json_get_all_users_3[
    json_get_all_users_3[const.METRIC_NAME].isin(metric_row_selection)
]

## Pod Report
json_get_all_users_pod_1 = pd.read_csv(
    const.JSON_GET_ALL_USERS_POD_1, usecols=metric_selection_pods
)
json_get_all_users_pod_2 = pd.read_csv(
    const.JSON_GET_ALL_USERS_POD_2, usecols=metric_selection_pods
)
json_get_all_users_pod_3 = pd.read_csv(
    const.JSON_GET_ALL_USERS_POD_3, usecols=metric_selection_pods
)

# Gateway Pod Report
json_get_all_users_gateway_pod_1 = pd.read_csv(
    const.JSON_GET_ALL_USERS_POD_GATEWAY_1, usecols=metric_selection_pods
)
json_get_all_users_gateway_pod_2 = pd.read_csv(
    const.JSON_GET_ALL_USERS_POD_GATEWAY_2, usecols=metric_selection_pods
)
json_get_all_users_gateway_pod_3 = pd.read_csv(
    const.JSON_GET_ALL_USERS_POD_GATEWAY_3, usecols=metric_selection_pods
)

# Get User by ID
## Normal Report
json_get_user_id_1 = pd.read_csv(
    const.JSON_GET_USER_ID_1, usecols=metric_selection
)
json_get_user_id_1 = json_get_user_id_1[
    json_get_user_id_1[const.METRIC_NAME].isin(metric_row_selection)
]

json_get_user_id_2 = pd.read_csv(
    const.JSON_GET_USER_ID_2, usecols=metric_selection
)
json_get_user_id_2 = json_get_user_id_2[
    json_get_user_id_2[const.METRIC_NAME].isin(metric_row_selection)
]

json_get_user_id_3 = pd.read_csv(
    const.JSON_GET_USER_ID_3, usecols=metric_selection
)
json_get_user_id_3 = json_get_user_id_3[
    json_get_user_id_3[const.METRIC_NAME].isin(metric_row_selection)
]

## Pod Report
json_get_user_id_pod_1 = pd.read_csv(
    const.JSON_GET_USER_ID_POD_1, usecols=metric_selection_pods
)
json_get_user_id_pod_2 = pd.read_csv(
    const.JSON_GET_USER_ID_POD_2, usecols=metric_selection_pods
)
json_get_user_id_pod_3 = pd.read_csv(
    const.JSON_GET_USER_ID_POD_3, usecols=metric_selection_pods
)

# Gateway Pod Report
json_get_user_id_gateway_pod_1 = pd.read_csv(
    const.JSON_GET_USER_ID_POD_GATEWAY_1, usecols=metric_selection_pods
)
json_get_user_id_gateway_pod_2 = pd.read_csv(
    const.JSON_GET_USER_ID_POD_GATEWAY_2, usecols=metric_selection_pods
)
json_get_user_id_gateway_pod_3 = pd.read_csv(
    const.JSON_GET_USER_ID_POD_GATEWAY_3, usecols=metric_selection_pods
)

# Get all Products entities
## Normal Report
json_get_all_product_entities_1 = pd.read_csv(
    const.JSON_GET_ALL_PRODUCT_ENTITIES_1, usecols=metric_selection
)
json_get_all_product_entities_1 = json_get_all_product_entities_1[
    json_get_all_product_entities_1[const.METRIC_NAME].isin(metric_row_selection)
]

json_get_all_product_entities_2 = pd.read_csv(
    const.JSON_GET_ALL_PRODUCT_ENTITIES_2, usecols=metric_selection
)
json_get_all_product_entities_2 = json_get_all_product_entities_2[
    json_get_all_product_entities_2[const.METRIC_NAME].isin(metric_row_selection)
]

json_get_all_product_entities_3 = pd.read_csv(
    const.JSON_GET_ALL_PRODUCT_ENTITIES_3, usecols=metric_selection
)
json_get_all_product_entities_3 = json_get_all_product_entities_3[
    json_get_all_product_entities_3[const.METRIC_NAME].isin(metric_row_selection)
]

## Pod Report
json_get_all_product_entities_pod_1 = pd.read_csv(
    const.JSON_GET_ALL_PRODUCT_ENTITIES_POD_1, usecols=metric_selection_pods
)
json_get_all_product_entities_pod_2 = pd.read_csv(
    const.JSON_GET_ALL_PRODUCT_ENTITIES_POD_2, usecols=metric_selection_pods
)
json_get_all_product_entities_pod_3 = pd.read_csv(
    const.JSON_GET_ALL_PRODUCT_ENTITIES_POD_3, usecols=metric_selection_pods
)
# Gateway Pod Report
json_get_all_product_entities_gateway_pod_1 = pd.read_csv(
    const.JSON_GET_ALL_PRODUCT_ENTITIES_POD_GATEWAY_1,
    usecols=metric_selection_pods,
)
json_get_all_product_entities_gateway_pod_2 = pd.read_csv(
    const.JSON_GET_ALL_PRODUCT_ENTITIES_POD_GATEWAY_2,
    usecols=metric_selection_pods,
)
json_get_all_product_entities_gateway_pod_3 = pd.read_csv(
    const.JSON_GET_ALL_PRODUCT_ENTITIES_POD_GATEWAY_3,
    usecols=metric_selection_pods,
)

# Update User
## Normal Report
json_update_user_1 = pd.read_csv(
    const.JSON_UPDATE_USER_1, usecols=metric_selection
)
json_update_user_1 = json_update_user_1[
    json_update_user_1[const.METRIC_NAME].isin(metric_row_selection)
]
json_update_user_2 = pd.read_csv(
    const.JSON_UPDATE_USER_2, usecols=metric_selection
)
json_update_user_2 = json_update_user_2[
    json_update_user_2[const.METRIC_NAME].isin(metric_row_selection)
]
json_update_user_3 = pd.read_csv(
    const.JSON_UPDATE_USER_3, usecols=metric_selection
)
json_update_user_3 = json_update_user_3[
    json_update_user_3[const.METRIC_NAME].isin(metric_row_selection)
]
## Pod Report
json_update_user_pod_1 = pd.read_csv(
    const.JSON_UPDATE_USER_POD_1, usecols=metric_selection_pods
)
json_update_user_pod_2 = pd.read_csv(
    const.JSON_UPDATE_USER_POD_2, usecols=metric_selection_pods
)
json_update_user_pod_3 = pd.read_csv(
    const.JSON_UPDATE_USER_POD_3, usecols=metric_selection_pods
)
# Gateway Pod Report
json_update_user_gateway_pod_1 = pd.read_csv(
    const.JSON_UPDATE_USER_POD_GATEWAY_1, usecols=metric_selection_pods
)
json_update_user_gateway_pod_2 = pd.read_csv(
    const.JSON_UPDATE_USER_POD_GATEWAY_2, usecols=metric_selection_pods
)
json_update_user_gateway_pod_3 = pd.read_csv(
    const.JSON_UPDATE_USER_POD_GATEWAY_3, usecols=metric_selection_pods
)


# Delete User
## Normal Report
json_delete_user_1 = pd.read_csv(
    const.JSON_DELETE_USER_1, usecols=metric_selection
)
json_delete_user_1 = json_delete_user_1[
    json_delete_user_1[const.METRIC_NAME].isin(metric_row_selection)
]
json_delete_user_2 = pd.read_csv(
    const.JSON_DELETE_USER_2, usecols=metric_selection
)
json_delete_user_2 = json_delete_user_2[
    json_delete_user_2[const.METRIC_NAME].isin(metric_row_selection)
]
json_delete_user_3 = pd.read_csv(
    const.JSON_DELETE_USER_3, usecols=metric_selection
)
json_delete_user_3 = json_delete_user_3[
    json_delete_user_3[const.METRIC_NAME].isin(metric_row_selection)
]
## Pod Report
json_delete_user_pod_1 = pd.read_csv(
    const.JSON_DELETE_USER_POD_1, usecols=metric_selection_pods
)
json_delete_user_pod_2 = pd.read_csv(
    const.JSON_DELETE_USER_POD_2, usecols=metric_selection_pods
)
json_delete_user_pod_3 = pd.read_csv(
    const.JSON_DELETE_USER_POD_3, usecols=metric_selection_pods
)

# Gateway Pod Report
json_delete_user_gateway_pod_1 = pd.read_csv(
    const.JSON_DELETE_USER_POD_GATEWAY_1, usecols=metric_selection_pods
)
json_delete_user_gateway_pod_2 = pd.read_csv(
    const.JSON_DELETE_USER_POD_GATEWAY_2, usecols=metric_selection_pods
)
json_delete_user_gateway_pod_3 = pd.read_csv(
    const.JSON_DELETE_USER_POD_GATEWAY_3, usecols=metric_selection_pods
)

# Create User
## Normal Report
protobuf_create_user_1 = pd.read_csv(
    const.PROTOBUF_CREATE_USER_1, usecols=metric_selection
)
protobuf_create_user_1 = protobuf_create_user_1[
    protobuf_create_user_1[const.METRIC_NAME].isin(metric_row_selection)
]

protobuf_create_user_2 = pd.read_csv(
    const.PROTOBUF_CREATE_USER_2, usecols=metric_selection
)
protobuf_create_user_2 = protobuf_create_user_2[
    protobuf_create_user_2[const.METRIC_NAME].isin(metric_row_selection)
]

protobuf_create_user_3 = pd.read_csv(
    const.PROTOBUF_CREATE_USER_3, usecols=metric_selection
)
protobuf_create_user_3 = protobuf_create_user_3[
    protobuf_create_user_3[const.METRIC_NAME].isin(metric_row_selection)
]

## Pod Report
protobuf_create_user_pod_1 = pd.read_csv(
    const.PROTOBUF_CREATE_USER_POD_1, usecols=metric_selection_pods
)
protobuf_create_user_pod_2 = pd.read_csv(
    const.PROTOBUF_CREATE_USER_POD_2, usecols=metric_selection_pods
)
protobuf_create_user_pod_3 = pd.read_csv(
    const.PROTOBUF_CREATE_USER_POD_3, usecols=metric_selection_pods
)
## Gateway Pod Report
protobuf_create_user_gateway_pod_1 = pd.read_csv(
    const.PROTOBUF_CREATE_USER_POD_GATEWAY_1, usecols=metric_selection_pods
)
protobuf_create_user_gateway_pod_2 = pd.read_csv(
    const.PROTOBUF_CREATE_USER_POD_GATEWAY_2, usecols=metric_selection_pods
)
protobuf_create_user_gateway_pod_3 = pd.read_csv(
    const.PROTOBUF_CREATE_USER_POD_GATEWAY_3, usecols=metric_selection_pods
)


# Get all Users
## Normal Report
protobuf_get_all_users_1 = pd.read_csv(
    const.PROTOBUF_GET_ALL_USERS_1, usecols=metric_selection
)
protobuf_get_all_users_1 = protobuf_get_all_users_1[
    protobuf_get_all_users_1[const.METRIC_NAME].isin(metric_row_selection)
]

protobuf_get_all_users_2 = pd.read_csv(
    const.PROTOBUF_GET_ALL_USERS_2, usecols=metric_selection
)
protobuf_get_all_users_2 = protobuf_get_all_users_2[
    protobuf_get_all_users_2[const.METRIC_NAME].isin(metric_row_selection)
]

protobuf_get_all_users_3 = pd.read_csv(
    const.PROTOBUF_GET_ALL_USERS_3, usecols=metric_selection
)
protobuf_get_all_users_3 = protobuf_get_all_users_3[
    protobuf_get_all_users_3[const.METRIC_NAME].isin(metric_row_selection)
]

## Pod Report
protobuf_get_all_users_pod_1 = pd.read_csv(
    const.PROTOBUF_GET_ALL_USERS_POD_1, usecols=metric_selection_pods
)
protobuf_get_all_users_pod_2 = pd.read_csv(
    const.PROTOBUF_GET_ALL_USERS_POD_2, usecols=metric_selection_pods
)
protobuf_get_all_users_pod_3 = pd.read_csv(
    const.PROTOBUF_GET_ALL_USERS_POD_3, usecols=metric_selection_pods
)
# Gateway Pod Report
protobuf_get_all_users_gateway_pod_1 = pd.read_csv(
    const.PROTOBUF_GET_ALL_USERS_POD_GATEWAY_1, usecols=metric_selection_pods
)
protobuf_get_all_users_gateway_pod_2 = pd.read_csv(
    const.PROTOBUF_GET_ALL_USERS_POD_GATEWAY_2, usecols=metric_selection_pods
)
protobuf_get_all_users_gateway_pod_3 = pd.read_csv(
    const.PROTOBUF_GET_ALL_USERS_POD_GATEWAY_3, usecols=metric_selection_pods
)
# Get User by ID
## Normal Report
protobuf_get_user_id_1 = pd.read_csv(
    const.PROTOBUF_GET_USER_ID_1, usecols=metric_selection
)
protobuf_get_user_id_1 = protobuf_get_user_id_1[
    protobuf_get_user_id_1[const.METRIC_NAME].isin(metric_row_selection)
]

protobuf_get_user_id_2 = pd.read_csv(
    const.PROTOBUF_GET_USER_ID_2, usecols=metric_selection
)
protobuf_get_user_id_2 = protobuf_get_user_id_2[
    protobuf_get_user_id_2[const.METRIC_NAME].isin(metric_row_selection)
]

protobuf_get_user_id_3 = pd.read_csv(
    const.PROTOBUF_GET_USER_ID_3, usecols=metric_selection
)
protobuf_get_user_id_3 = protobuf_get_user_id_3[
    protobuf_get_user_id_3[const.METRIC_NAME].isin(metric_row_selection)
]

## Pod Report
protobuf_get_user_id_pod_1 = pd.read_csv(
    const.PROTOBUF_GET_USER_ID_POD_1, usecols=metric_selection_pods
)
protobuf_get_user_id_pod_2 = pd.read_csv(
    const.PROTOBUF_GET_USER_ID_POD_2, usecols=metric_selection_pods
)
protobuf_get_user_id_pod_3 = pd.read_csv(
    const.PROTOBUF_GET_USER_ID_POD_3, usecols=metric_selection_pods
)
# Gateway Pod Report
protobuf_get_user_id_gateway_pod_1 = pd.read_csv(
    const.PROTOBUF_GET_USER_ID_POD_GATEWAY_1, usecols=metric_selection_pods
)
protobuf_get_user_id_gateway_pod_2 = pd.read_csv(
    const.PROTOBUF_GET_USER_ID_POD_GATEWAY_2, usecols=metric_selection_pods
)
protobuf_get_user_id_gateway_pod_3 = pd.read_csv(
    const.PROTOBUF_GET_USER_ID_POD_GATEWAY_3, usecols=metric_selection_pods
)

# Get all Products entities
## Normal Report
protobuf_get_all_product_entities_1 = pd.read_csv(
    const.PROTOBUF_GET_ALL_PRODUCT_ENTITIES_1, usecols=metric_selection
)
protobuf_get_all_product_entities_1 = protobuf_get_all_product_entities_1[
    protobuf_get_all_product_entities_1[const.METRIC_NAME].isin(metric_row_selection)
]

protobuf_get_all_product_entities_2 = pd.read_csv(
    const.PROTOBUF_GET_ALL_PRODUCT_ENTITIES_2, usecols=metric_selection
)
protobuf_get_all_product_entities_2 = protobuf_get_all_product_entities_2[
    protobuf_get_all_product_entities_2[const.METRIC_NAME].isin(metric_row_selection)
]

protobuf_get_all_product_entities_3 = pd.read_csv(
    const.PROTOBUF_GET_ALL_PRODUCT_ENTITIES_3, usecols=metric_selection
)
protobuf_get_all_product_entities_3 = protobuf_get_all_product_entities_3[
    protobuf_get_all_product_entities_3[const.METRIC_NAME].isin(metric_row_selection)
]

## Pod Report
protobuf_get_all_product_entities_pod_1 = pd.read_csv(
    const.PROTOBUF_GET_ALL_PRODUCT_ENTITIES_POD_1,
    usecols=metric_selection_pods,
)
protobuf_get_all_product_entities_pod_2 = pd.read_csv(
    const.PROTOBUF_GET_ALL_PRODUCT_ENTITIES_POD_2,
    usecols=metric_selection_pods,
)
protobuf_get_all_product_entities_pod_3 = pd.read_csv(
    const.PROTOBUF_GET_ALL_PRODUCT_ENTITIES_POD_3,
    usecols=metric_selection_pods,
)
# Gateway Pod Report
protobuf_get_all_product_entities_gateway_pod_1 = pd.read_csv(
    const.PROTOBUF_GET_ALL_PRODUCT_ENTITIES_POD_GATEWAY_1,
    usecols=metric_selection_pods,
)
protobuf_get_all_product_entities_gateway_pod_2 = pd.read_csv(
    const.PROTOBUF_GET_ALL_PRODUCT_ENTITIES_POD_GATEWAY_2,
    usecols=metric_selection_pods,
)
protobuf_get_all_product_entities_gateway_pod_3 = pd.read_csv(
    const.PROTOBUF_GET_ALL_PRODUCT_ENTITIES_POD_GATEWAY_3,
    usecols=metric_selection_pods,
)

# Update User
## Normal Report
protobuf_update_user_1 = pd.read_csv(
    const.PROTOBUF_UPDATE_USER_1, usecols=metric_selection
)
protobuf_update_user_1 = protobuf_update_user_1[
    protobuf_update_user_1[const.METRIC_NAME].isin(metric_row_selection)
]
protobuf_update_user_2 = pd.read_csv(
    const.PROTOBUF_UPDATE_USER_2, usecols=metric_selection
)
protobuf_update_user_2 = protobuf_update_user_2[
    protobuf_update_user_2[const.METRIC_NAME].isin(metric_row_selection)
]
protobuf_update_user_3 = pd.read_csv(
    const.PROTOBUF_UPDATE_USER_3, usecols=metric_selection
)
protobuf_update_user_3 = protobuf_update_user_3[
    protobuf_update_user_3[const.METRIC_NAME].isin(metric_row_selection)
]
## Pod Report
protobuf_update_user_pod_1 = pd.read_csv(
    const.PROTOBUF_UPDATE_USER_POD_1, usecols=metric_selection_pods
)
protobuf_update_user_pod_2 = pd.read_csv(
    const.PROTOBUF_UPDATE_USER_POD_2, usecols=metric_selection_pods
)
protobuf_update_user_pod_3 = pd.read_csv(
    const.PROTOBUF_UPDATE_USER_POD_3, usecols=metric_selection_pods
)
# Gateway Pod Report
protobuf_update_user_gateway_pod_1 = pd.read_csv(
    const.PROTOBUF_UPDATE_USER_POD_GATEWAY_1, usecols=metric_selection_pods
)
protobuf_update_user_gateway_pod_2 = pd.read_csv(
    const.PROTOBUF_UPDATE_USER_POD_GATEWAY_2, usecols=metric_selection_pods
)
protobuf_update_user_gateway_pod_3 = pd.read_csv(
    const.PROTOBUF_UPDATE_USER_POD_GATEWAY_3, usecols=metric_selection_pods
)

# Delete User
## Normal Report
protobuf_delete_user_1 = pd.read_csv(
    const.PROTOBUF_DELETE_USER_1, usecols=metric_selection
)
protobuf_delete_user_1 = protobuf_delete_user_1[
    protobuf_delete_user_1[const.METRIC_NAME].isin(metric_row_selection)
]
protobuf_delete_user_2 = pd.read_csv(
    const.PROTOBUF_DELETE_USER_2, usecols=metric_selection
)
protobuf_delete_user_2 = protobuf_delete_user_2[
    protobuf_delete_user_2[const.METRIC_NAME].isin(metric_row_selection)
]
protobuf_delete_user_3 = pd.read_csv(
    const.PROTOBUF_DELETE_USER_3, usecols=metric_selection
)
protobuf_delete_user_3 = protobuf_delete_user_3[
    protobuf_delete_user_3[const.METRIC_NAME].isin(metric_row_selection)
]
## Pod Report
protobuf_delete_user_pod_1 = pd.read_csv(
    const.PROTOBUF_DELETE_USER_POD_1, usecols=metric_selection_pods
)
protobuf_delete_user_pod_2 = pd.read_csv(
    const.PROTOBUF_DELETE_USER_POD_2, usecols=metric_selection_pods
)
protobuf_delete_user_pod_3 = pd.read_csv(
    const.PROTOBUF_DELETE_USER_POD_3, usecols=metric_selection_pods
)

# Gateway Pod Report
protobuf_delete_user_gateway_pod_1 = pd.read_csv(
    const.PROTOBUF_DELETE_USER_POD_GATEWAY_1, usecols=metric_selection_pods
)
protobuf_delete_user_gateway_pod_2 = pd.read_csv(
    const.PROTOBUF_DELETE_USER_POD_GATEWAY_2, usecols=metric_selection_pods
)
protobuf_delete_user_gateway_pod_3 = pd.read_csv(
    const.PROTOBUF_DELETE_USER_POD_GATEWAY_3, usecols=metric_selection_pods
)

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# ### Initialize constants and table data

# %%
endpoints = [
    "create_user",
    "get_all_users",
    "get_user_id",
    "get_all_product_entities",
    "update_user",
    "delete_user",
]


def compute_percentage_difference(a, b, is_lesser_better=True):
    if a == 0 or b == 0:
        return (0, False)

    if is_lesser_better:
        # For metrics where lower is better (e.g., response time)
        if b < a:
            improvement = ((a - b) / a) * 100
            return (round(improvement, 2), True)
        else:
            improvement = ((b - a) / a) * 100
            return (round(improvement, 2), False)
    else:
        # For metrics where higher is better (e.g., throughput)
        if b > a:
            improvement = ((b - a) / a) * 100
            return (round(improvement, 2), True)
        else:
            improvement = ((a - b) / a) * 100
            return (round(improvement, 2), False)


def calculate_throughput(timestamps):
    timestamp_counts = Counter(timestamps)
    throughput_array = np.zeros(len(timestamps))

    for i, ts in enumerate(timestamps):
        throughput_array[i] = timestamp_counts[ts]

    # Calculate mean throughput
    mean_throughput = round(np.mean(throughput_array), 2)
    median_throughput = round(np.median(throughput_array), 2)
    return throughput_array, mean_throughput, median_throughput


def extract_response_times(df, metric_col, value_col, target_metric):
    return df[df[metric_col] == target_metric][value_col].values


def extract_energy_consumption(df, columns_names):
    combined_list = []
    for column in columns_names:
        combined_list.extend(df[column].values)
    return combined_list


def display_percentage_difference_energy(df):

    diff_total_joules = compute_percentage_difference(
        df["Total Joules"].values[0], df["Total Joules"].values[1]
    )
    diff_average_total_joules = compute_percentage_difference(
        df["Total Average Joules"].values[0], df["Total Average Joules"].values[1]
    )
    diff_average_joules = compute_percentage_difference(
        df["Average Joules"].values[0], df["Average Joules"].values[1]
    )
    diff_median_joules = compute_percentage_difference(
        df["Median Joules"].values[0], df["Median Joules"].values[1]
    )
    diff_max_joules = compute_percentage_difference(
        df["maximum Joules"].values[0], df["maximum Joules"].values[1]
    )
    diff_min_joules = compute_percentage_difference(
        df["minimum Joules"].values[0], df["minimum Joules"].values[1]
    )
    diff_std_joules = compute_percentage_difference(
        df["std"].values[0], df["std"].values[1]
    )
    diff_joules_per_request = compute_percentage_difference(
        df["Joules per Request"].values[0], df["Joules per Request"].values[1]
    )

    diff_table = pd.DataFrame(
        {
            "Total Joules": [diff_total_joules],
            "Total Average Joules": [diff_average_total_joules],
            "Average Joules": [diff_average_joules],
            "Median Joules": [diff_median_joules],
            "maximum Joules": [diff_max_joules],
            "minimum Joules": [diff_min_joules],
            "std": [diff_std_joules],
            "Joules per Request": [diff_joules_per_request],
        }
    )
    return diff_table


def display_tables(tables, titles, difference_func, debug=False):
    if debug:
        for i, table_set in enumerate(tables):
            if len(table_set) == 2:
                json_table, protobuf_table = table_set
                concatenated_table = pd.concat([json_table, protobuf_table])
                # print(f"\n{titles[i]} TABLE")
                display(Markdown(f"## {titles[i]}"))
                display(concatenated_table)

                # print(f"\n{titles[i]} PERCENTAGE DIFFERENCE")
                display(Markdown(f"## {titles[i]} Percentage Difference"))
                diff_table = difference_func(concatenated_table)
                display(diff_table)
            else:
                print(
                    f"\nError: Expected a list of two tables for '{titles[i]}', but got {len(table_set)}"
                )

def print_meta_analysis(list_of_values, titles, debug=False):
    if debug:
        for i, values in enumerate(list_of_values):
            print(f"Title : {titles[i]}")
            print(f"Mean: {np.mean(values):.2f}")
            print(f"Median: {np.median(values):.2f}")
            print(f"Standard Deviation: {np.std(values, ddof=1):.2f}")
            print(f"Variance: {np.var(values, ddof=1):.2f}")
            print(f"Minimum: {np.min(values):.2f}")
            print(f"Maximum: {np.max(values):.2f}")
            print("\n")


def compare_iterations(protobuf_data, json_data):
    """Compares JSON vs. Protobuf for each iteration separately."""
    json_norm_p = normaltest(json_data).pvalue
    proto_norm_p = normaltest(protobuf_data).pvalue
    var_p = levene(protobuf_data, json_data).pvalue

    if json_norm_p > 0.05 and proto_norm_p > 0.05:
        _, p_val = ttest_ind(protobuf_data, json_data, equal_var=(var_p >= 0.05))
        test_name = "t-test"
    else:
        _, p_val = mannwhitneyu(protobuf_data, json_data, alternative="less")
        test_name = "Mann-Whitney U"
    return {
        "p_value": p_val,
        "test_used": test_name,
        "json_median": np.median(json_data),
        "protobuf_median": np.median(protobuf_data),
        "is_significant": (
            "The difference is significant"
            if p_val < 0.05
            else "The difference is not significant"
        ),
    }


json_all_response_times = np.concatenate(
    [
        extract_response_times(
            df, const.METRIC_NAME, const.METRIC_VALUE, const.RESPONSE_TIME
        )
        for df in [
            json_create_user_1,
            json_create_user_2,
            json_create_user_3,
            json_get_all_users_1,
            json_get_all_users_2,
            json_get_all_users_3,
            json_get_user_id_1,
            json_get_user_id_2,
            json_get_user_id_3,
            json_get_all_product_entities_1,
            json_get_all_product_entities_2,
            json_get_all_product_entities_3,
            json_update_user_1,
            json_update_user_2,
            json_update_user_3,
            json_delete_user_1,
            json_delete_user_2,
            json_delete_user_3,
        ]
    ]
)

protobuf_all_response_times = np.concatenate(
    [
        extract_response_times(
            df, const.METRIC_NAME, const.METRIC_VALUE, const.RESPONSE_TIME
        )
        for df in [
            protobuf_create_user_1,
            protobuf_create_user_2,
            protobuf_create_user_3,
            protobuf_get_all_users_1,
            protobuf_get_all_users_2,
            protobuf_get_all_users_3,
            protobuf_get_user_id_1,
            protobuf_get_user_id_2,
            protobuf_get_user_id_3,
            protobuf_get_all_product_entities_1,
            protobuf_get_all_product_entities_2,
            protobuf_get_all_product_entities_3,
            protobuf_update_user_1,
            protobuf_update_user_2,
            protobuf_update_user_3,
            protobuf_delete_user_1,
            protobuf_delete_user_2,
            protobuf_delete_user_3,
        ]
    ]
)

json_reports = [
    [json_create_user_1],
    [json_get_all_users_1],
    [json_get_user_id_1],
    [json_get_all_product_entities_1],
    [json_update_user_1],
    [json_delete_user_1],
]

protobuf_reports = [
    [protobuf_create_user_1],
    [protobuf_get_all_users_1],
    [protobuf_get_user_id_1],
    [
        protobuf_get_all_product_entities_1,
    ],
    [protobuf_update_user_1],
    [protobuf_delete_user_1],
]


json_all_pod_reports = np.concatenate(
    [
        extract_energy_consumption(df, [const.TOTAL])
        for df in [
            json_create_user_pod_1,
            json_create_user_pod_2,
            json_create_user_pod_3,
            json_get_all_users_pod_1,
            json_get_all_users_pod_2,
            json_get_all_users_pod_3,
            json_get_user_id_pod_1,
            json_get_user_id_pod_2,
            json_get_user_id_pod_3,
            json_get_all_product_entities_pod_1,
            json_get_all_product_entities_pod_2,
            json_get_all_product_entities_pod_3,
            json_update_user_pod_1,
            json_update_user_pod_2,
            json_update_user_pod_3,
            json_delete_user_pod_1,
            json_delete_user_pod_2,
            json_delete_user_pod_3,
        ]
    ]
)
json_all_gateway_pod_reports = np.concatenate(
    [
        extract_energy_consumption(df, [const.TOTAL])
        for df in [
            json_create_user_gateway_pod_1,
            json_create_user_gateway_pod_2,
            json_create_user_gateway_pod_3,
            json_get_all_users_gateway_pod_1,
            json_get_all_users_gateway_pod_2,
            json_get_all_users_gateway_pod_3,
            json_get_user_id_gateway_pod_1,
            json_get_user_id_gateway_pod_2,
            json_get_user_id_gateway_pod_3,
            json_get_all_product_entities_gateway_pod_1,
            json_get_all_product_entities_gateway_pod_2,
            json_get_all_product_entities_gateway_pod_3,
            json_update_user_gateway_pod_1,
            json_update_user_gateway_pod_2,
            json_update_user_gateway_pod_3,
            json_delete_user_gateway_pod_1,
            json_delete_user_gateway_pod_2,
            json_delete_user_gateway_pod_3,
        ]
    ]
)

protobuf_all_pod_reports = np.concatenate(
    [
        extract_energy_consumption(df, [const.TOTAL])
        for df in [
            protobuf_create_user_pod_1,
            protobuf_create_user_pod_2,
            protobuf_create_user_pod_3,
            protobuf_get_all_users_pod_1,
            protobuf_get_all_users_pod_2,
            protobuf_get_all_users_pod_3,
            protobuf_get_user_id_pod_1,
            protobuf_get_user_id_pod_2,
            protobuf_get_user_id_pod_3,
            protobuf_get_all_product_entities_pod_1,
            protobuf_get_all_product_entities_pod_2,
            protobuf_get_all_product_entities_pod_3,
            protobuf_update_user_pod_1,
            protobuf_update_user_pod_2,
            protobuf_update_user_pod_3,
            protobuf_delete_user_pod_1,
            protobuf_delete_user_pod_2,
            protobuf_delete_user_pod_3,
        ]
    ]
)

protobuf_all_gateway_pod_reports = np.concatenate(
    [
        extract_energy_consumption(df, [const.TOTAL])
        for df in [
            protobuf_create_user_gateway_pod_1,
            protobuf_create_user_gateway_pod_2,
            protobuf_create_user_gateway_pod_3,
            protobuf_get_all_users_gateway_pod_1,
            protobuf_get_all_users_gateway_pod_2,
            protobuf_get_all_users_gateway_pod_3,
            protobuf_get_user_id_gateway_pod_1,
            protobuf_get_user_id_gateway_pod_2,
            protobuf_get_user_id_gateway_pod_3,
            protobuf_get_all_product_entities_gateway_pod_1,
            protobuf_get_all_product_entities_gateway_pod_2,
            protobuf_get_all_product_entities_gateway_pod_3,
            protobuf_update_user_gateway_pod_1,
            protobuf_update_user_gateway_pod_2,
            protobuf_update_user_gateway_pod_3,
            protobuf_delete_user_gateway_pod_1,
            protobuf_delete_user_gateway_pod_2,
            protobuf_delete_user_gateway_pod_3,
        ]
    ]
)

json_pod_reports = [
    [json_create_user_pod_1],
    [json_get_all_users_pod_1],
    [json_get_user_id_pod_1],
    [
        json_get_all_product_entities_pod_1,

    ],
    [json_update_user_pod_1],
    [json_delete_user_pod_1],
]
json_pod_gateway_reports = [
    [
        json_create_user_gateway_pod_1,
    ],
    [
        json_get_all_users_gateway_pod_1,
    ],
    [
        json_get_user_id_gateway_pod_1,
    ],
    [
        json_get_all_product_entities_gateway_pod_1,
    ],
    [
        json_update_user_gateway_pod_1,
    ],
    [
        json_delete_user_gateway_pod_1,
    ],
]

protobuf_pod_reports = [
    [
        protobuf_create_user_pod_1,
    ],
    [
        protobuf_get_all_users_pod_1,
    ],
    [
        protobuf_get_user_id_pod_1,
    ],
    [
        protobuf_get_all_product_entities_pod_1,
    ],
    [
        protobuf_update_user_pod_1,
    ],
    [
        protobuf_delete_user_pod_1,
    ],
]

protobuf_pod_gateway_reports = [
    [
        protobuf_create_user_gateway_pod_1,
    ],
    [
        protobuf_get_all_users_gateway_pod_1,
    ],
    [
        protobuf_get_user_id_gateway_pod_1,
    ],
    [
        protobuf_get_all_product_entities_gateway_pod_1,
    ],
    [
        protobuf_update_user_gateway_pod_1,
    ],
    [
        protobuf_delete_user_gateway_pod_1,
    ],
]

# %% [markdown]
# ### Performance

# %% [markdown]
# #### Global Performance

# %%
json_median = np.median(json_all_response_times)
protobuf_median = np.median(protobuf_all_response_times)

delta, res = cliffs_delta(protobuf_all_response_times, json_all_response_times)

_, p_median, _, _ = median_test(protobuf_all_response_times, json_all_response_times)

print(f"JSON Median Response Time: {json_median}")
print(f"Protobuf Median Response Time: {protobuf_median}")
print(
    f"Cliff’s Delta: {delta} (Interpretation: Small <0.147, Medium <0.33, Large >0.33)"
)
print(f"Median Test p-value: {p_median}")
# Out:
# JSON Median Response Time: 6.951022999999999
# Protobuf Median Response Time: 6.4787230000000005
# Cliff’s Delta: -0.07214568209876543 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# Median Test p-value: 7.827006293869918e-26

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(json_all_response_times, label="JSON", fill=True)
sns.kdeplot(protobuf_all_response_times, label="Protobuf", fill=True)
plt.xlabel("Response Time (ms)")
plt.ylabel("Density")
plt.title("Response Time Distribution")
plt.legend()
plt.show()

# %%
# Normality test
json_normality_p = normaltest(json_all_response_times).pvalue
protobuf_normality_p = normaltest(protobuf_all_response_times).pvalue

# Variance test
variance_p = levene(protobuf_all_response_times, json_all_response_times).pvalue

# %%
if json_normality_p > 0.05 and protobuf_normality_p > 0.05:
    test_stat, p_value = ttest_ind(
        protobuf_all_response_times,
        json_all_response_times,
        equal_var=(variance_p >= 0.05),
    )
    test_name = "t-test"
else:
    test_stat, p_value = mannwhitneyu(
        protobuf_all_response_times, json_all_response_times, alternative="two-sided"
    )
    test_name = "Mann-Whitney U test"

print(f"Aggregated Performance Test ({test_name})")
print(f"p-value: {p_value}")
if p_value < 0.05:
    print("Significant difference found!\n")
else:
    print("No significant difference.\n")
# Out:
# Aggregated Performance Test (Mann-Whitney U test)
# p-value: 2.0374298472951442e-32
# Significant difference found!

# %% [markdown]
# #### Per EndPoint Performance

# %%
def histogram_plot_data(df, title, label):
    plt.figure(figsize=(10, 6))
    sns.histplot(df, kde=True, stat="density")
    plt.axvline(0, color="red", linestyle="--")
    plt.title(
        title
    )
    plt.xlabel(label)
    plt.ylabel("Density")
    plt.show()

# %%
def bootstrap_probability(a, b, n_bootsraps=10000):
    """
    Calculate the probability that the mean of a is greater than the mean of b using bootstrapping.
    
    Parameters:
    a (array-like): The first sample.
    b (array-like): The second sample.
    n_bootsraps (int): The number of bootstrap samples to take.
    
    Returns:
    p (float): The probability that the mean of a is greater than the mean of b.
    diffs (array): The differences in means from each bootstrap sample.
    ci (tuple): The 95% confidence interval of the differences.
    """
    diffs = []
    n = len(a)
    m = len(b)
    for _ in range(n_bootsraps):
        a_sample = np.random.choice(a, size=n, replace=True)
        b_sample = np.random.choice(b, size=m, replace=True)

        diffs.append(np.mean(a_sample) - np.mean(b_sample))

    diffs = np.array(diffs)

    p = np.mean(diffs < 0)
    ci_low, ci_high = np.percentile(diffs, [2.5, 97.5])

    return p, diffs, (ci_low, ci_high)

# %%
def compute_throughput_statistics(report, position):
    mean = 0
    median = 0
    throughput_values = np.array([])
    for df in report[position]:
        timestamps = extract_response_times(
            df, const.METRIC_NAME, const.TIMESTAP, const.HTTP_REQ_DURATION
        )
        
        throughput, mean, median = calculate_throughput(timestamps)
        throughput_values = np.concatenate([throughput_values, throughput])
    return throughput_values, mean, median


def compute_response_times_statistics(
    serialization, endpoint, report, position,
):
    table_data = pd.DataFrame(
        columns=[
            "Serialization",
            "Endpoint",
            "Average Response Time (ms)",
            "Throughput (req/s)",
            "Median",
            "Maximum Response Time (ms)",
            "Minimum Response Time (ms)",
            "std",
        ]
    )

    response_times = np.concatenate(
        [
            extract_response_times(
                df, const.METRIC_NAME, const.METRIC_VALUE, const.RESPONSE_TIME
            )
            for df in report[position] 
        ]
    )

    average_response_time = round(np.mean(response_times),2)
    median_response_time = round(np.median(response_times),2)
    max_response_time = round(np.max(response_times),2)
    min_response_time = round(np.min(response_times),2)
    std_response_time = round(np.std(response_times),2)
    throughput_values, mean_throughput, _ = (
        compute_throughput_statistics(report, position)
    )

    table_data = pd.DataFrame(
        {
            "Serialization": [serialization],
            "Endpoint": [endpoint],
            "Average Response Time (ms)": [average_response_time],
            "Throughput (req/s)": [mean_throughput],
            "Median": [median_response_time],
            "Maximum Response Time (ms)": [max_response_time],
            "Minimum Response Time (ms)": [min_response_time],
            "std": [std_response_time],
        }
    )

    return table_data, response_times, throughput_values


def compute_percentage_difference_perfomance(df):
    df = df.reset_index(drop=True)
    diff_average_response_time = compute_percentage_difference(
        df["Average Response Time (ms)"][0], df["Average Response Time (ms)"][1]
    )
    diff_median_response_time = compute_percentage_difference(
        df["Median"][0], df["Median"][1]
    )
    diff_max_response_time = compute_percentage_difference(
        df["Maximum Response Time (ms)"][0], df["Maximum Response Time (ms)"][1]
    )
    diff_min_response_time = compute_percentage_difference(
        df["Minimum Response Time (ms)"][0], df["Minimum Response Time (ms)"][1]
    )
    diff_std_response_time = compute_percentage_difference(df["std"][0], df["std"][1])
    diff_throughput = compute_percentage_difference(
        df["Throughput (req/s)"][0], df["Throughput (req/s)"][1], False
    )
    diff_table = pd.DataFrame(
        {
            "Average Response Time (ms)": [diff_average_response_time],
            "Throughput (req/s)": [diff_throughput],
            "Median": [diff_median_response_time],
            "Maximum Response Time (ms)": [diff_max_response_time],
            "Minimum Response Time (ms)": [diff_min_response_time],
            "std": [diff_std_response_time],
        }
    )
    return diff_table

# %%
for i, endpoint in enumerate(endpoints):
    
    json_table_data,json_response_times,_ = compute_response_times_statistics(
        "JSON", endpoint,  json_reports, i
    )
    protobuf_table_data,protobuf_response_times,_ = compute_response_times_statistics(
        "Protobuf", endpoint,  protobuf_reports, i
    )

    display_tables(
       [ 
        [json_table_data, protobuf_table_data]
        ],
        [f"{endpoint} JSON vs Protobuf", f"{endpoint} JSON vs Protobuf Percentage Difference"],
        compute_percentage_difference_perfomance,
        debug=True,
    )

    print_meta_analysis(
        [json_response_times, protobuf_response_times],
        [f"{endpoint} JSON", f"{endpoint} Protobuf"],
        debug=True,
    )

    performance_results = compare_iterations(
        protobuf_response_times,
        json_response_times,
    )

    print("POD COMPARISON:")
    results = performance_results;
    print(f"Test Used: {results['test_used']}")
    print(f"p-value: {results['p_value']}")
    print(f"JSON Median: {results['json_median']}")
    print(f"Protobuf Median: {results['protobuf_median']}")
    print(f"Interpretation: {results['is_significant']}") 
    print("\n")
# Out:
# ## create_user JSON vs Protobuf
#   Serialization     Endpoint  Average Response Time (ms)  Throughput (req/s)  \
# 0          JSON  create_user                       94.42               10.63
# 0      Protobuf  create_user                       93.20               10.72
#
#    Median  Maximum Response Time (ms)  Minimum Response Time (ms)    std
# 0   91.47                      266.92                       59.49  22.52
# 0   90.23                      313.70                       61.21  23.55
# ## create_user JSON vs Protobuf Percentage Difference
#   Average Response Time (ms) Throughput (req/s)        Median  \
# 0               (1.29, True)       (0.85, True)  (1.36, True)
#
#   Maximum Response Time (ms) Minimum Response Time (ms)            std
# 0             (17.53, False)              (2.89, False)  (4.57, False)
# Title : create_user JSON
# Mean: 94.42
# Median: 91.47
# Standard Deviation: 22.53
# Variance: 507.49
# Minimum: 59.49
# Maximum: 266.92
#
#
# Title : create_user Protobuf
# Mean: 93.20
# Median: 90.23
# Standard Deviation: 23.56
# Variance: 555.24
# Minimum: 61.21
# Maximum: 313.70
#
#
# POD COMPARISON:
# Test Used: Mann-Whitney U
# p-value: 4.791562026110343e-06
# JSON Median: 91.47476499999999
# Protobuf Median: 90.2325175
# Interpretation: The difference is significant
# ## get_all_users JSON vs Protobuf
#   Serialization       Endpoint  Average Response Time (ms)  \
# 0          JSON  get_all_users                        5.47
# 0      Protobuf  get_all_users                        5.43
#
#    Throughput (req/s)  Median  Maximum Response Time (ms)  \
# 0              172.15    3.70                       67.19
# 0              168.80    3.61                       77.23
#
#    Minimum Response Time (ms)   std
# 0                        2.60  7.99
# 0                        2.08  8.57
# ## get_all_users JSON vs Protobuf Percentage Difference
#   Average Response Time (ms) Throughput (req/s)        Median  \
# 0               (0.73, True)      (1.95, False)  (2.43, True)
#
#   Maximum Response Time (ms) Minimum Response Time (ms)            std
# 0             (14.94, False)               (20.0, True)  (7.26, False)
# Title : get_all_users JSON
# Mean: 5.47
# Median: 3.70
# Standard Deviation: 7.99
# Variance: 63.87
# Minimum: 2.60
# Maximum: 67.19
#
#
# Title : get_all_users Protobuf
# Mean: 5.43
# Median: 3.61
# Standard Deviation: 8.58
# Variance: 73.60
# Minimum: 2.08
# Maximum: 77.23
#
#
# POD COMPARISON:
# Test Used: Mann-Whitney U
# p-value: 1.9667779960377295e-08
# JSON Median: 3.6975305
# Protobuf Median: 3.606327
# Interpretation: The difference is significant
# ## get_user_id JSON vs Protobuf
#   Serialization     Endpoint  Average Response Time (ms)  Throughput (req/s)  \
# 0          JSON  get_user_id                        5.31              186.49
# 0      Protobuf  get_user_id                        4.92              200.07
#
#    Median  Maximum Response Time (ms)  Minimum Response Time (ms)   std
# 0    3.15                       62.72                        2.04  8.84
# 0    3.06                       64.98                        1.88  8.34
# ## get_user_id JSON vs Protobuf Percentage Difference
#   Average Response Time (ms) Throughput (req/s)        Median  \
# 0               (7.34, True)       (7.28, True)  (2.86, True)
#
#   Maximum Response Time (ms) Minimum Response Time (ms)           std
# 0               (3.6, False)               (7.84, True)  (5.66, True)
# Title : get_user_id JSON
# Mean: 5.31
# Median: 3.15
# Standard Deviation: 8.84
# Variance: 78.18
# Minimum: 2.04
# Maximum: 62.72
#
#
# Title : get_user_id Protobuf
# Mean: 4.92
# Median: 3.06
# Standard Deviation: 8.34
# Variance: 69.59
# Minimum: 1.88
# Maximum: 64.98
#
#
# POD COMPARISON:
# Test Used: Mann-Whitney U
# p-value: 5.815314208996037e-06
# JSON Median: 3.147781
# Protobuf Median: 3.058508
# Interpretation: The difference is significant
# ## get_all_product_entities JSON vs Protobuf
#   Serialization                  Endpoint  Average Response Time (ms)  \
# 0          JSON  get_all_product_entities                       20.56
# 0      Protobuf  get_all_product_entities                       17.59
#
#    Throughput (req/s)  Median  Maximum Response Time (ms)  \
# 0               56.99    9.39                      602.92
# 0               60.99    6.74                      456.79
#
#    Minimum Response Time (ms)    std
# 0                        5.39  28.85
# 0                        3.99  24.55
# ## get_all_product_entities JSON vs Protobuf Percentage Difference
#   Average Response Time (ms) Throughput (req/s)         Median  \
# 0              (14.45, True)       (7.02, True)  (28.22, True)
#
#   Maximum Response Time (ms) Minimum Response Time (ms)           std
# 0              (24.24, True)              (25.97, True)  (14.9, True)
# Title : get_all_product_entities JSON
# Mean: 20.56
# Median: 9.39
# Standard Deviation: 28.86
# Variance: 832.90
# Minimum: 5.39
# Maximum: 602.92
#
#
# Title : get_all_product_entities Protobuf
# Mean: 17.59
# Median: 6.74
# Standard Deviation: 24.56
# Variance: 603.29
# Minimum: 3.99
# Maximum: 456.79
#
#
# POD COMPARISON:
# Test Used: Mann-Whitney U
# p-value: 7.429003316074337e-37
# JSON Median: 9.388895999999999
# Protobuf Median: 6.743964999999999
# Interpretation: The difference is significant
# ## update_user JSON vs Protobuf
#   Serialization     Endpoint  Average Response Time (ms)  Throughput (req/s)  \
# 0          JSON  update_user                       10.18               97.42
# 0      Protobuf  update_user                        9.61               97.86
#
#    Median  Maximum Response Time (ms)  Minimum Response Time (ms)   std
# 0    8.31                       90.52                        6.69  8.48
# 0    8.39                       74.04                        6.65  5.52
# ## update_user JSON vs Protobuf Percentage Difference
#   Average Response Time (ms) Throughput (req/s)         Median  \
# 0                (5.6, True)       (0.45, True)  (0.96, False)
#
#   Maximum Response Time (ms) Minimum Response Time (ms)            std
# 0              (18.21, True)                (0.6, True)  (34.91, True)
# Title : update_user JSON
# Mean: 10.18
# Median: 8.31
# Standard Deviation: 8.48
# Variance: 71.99
# Minimum: 6.69
# Maximum: 90.52
#
#
# Title : update_user Protobuf
# Mean: 9.61
# Median: 8.39
# Standard Deviation: 5.52
# Variance: 30.49
# Minimum: 6.65
# Maximum: 74.04
#
#
# POD COMPARISON:
# Test Used: Mann-Whitney U
# p-value: 0.8999062572328329
# JSON Median: 8.3068945
# Protobuf Median: 8.393405999999999
# Interpretation: The difference is not significant
# ## delete_user JSON vs Protobuf
#   Serialization     Endpoint  Average Response Time (ms)  Throughput (req/s)  \
# 0          JSON  delete_user                        8.84              106.49
# 0      Protobuf  delete_user                        8.29              116.43
#
#    Median  Maximum Response Time (ms)  Minimum Response Time (ms)   std
# 0    7.49                       74.59                         5.7  6.53
# 0    7.00                       75.73                         5.2  6.16
# ## delete_user JSON vs Protobuf Percentage Difference
#   Average Response Time (ms) Throughput (req/s)        Median  \
# 0               (6.22, True)       (9.33, True)  (6.54, True)
#
#   Maximum Response Time (ms) Minimum Response Time (ms)           std
# 0              (1.53, False)               (8.77, True)  (5.67, True)
# Title : delete_user JSON
# Mean: 8.84
# Median: 7.49
# Standard Deviation: 6.54
# Variance: 42.74
# Minimum: 5.70
# Maximum: 74.59
#
#
# Title : delete_user Protobuf
# Mean: 8.29
# Median: 7.00
# Standard Deviation: 6.17
# Variance: 38.04
# Minimum: 5.20
# Maximum: 75.73
#
#
# POD COMPARISON:
# Test Used: Mann-Whitney U
# p-value: 1.008239104754505e-17
# JSON Median: 7.493040499999999
# Protobuf Median: 7.003505499999999
# Interpretation: The difference is significant

# %%
### Throughput
for i, endpoint in enumerate(endpoints):

    print(f"Endpoint: {endpoint}")
    json_troughput_values = []

    for df in json_reports[i]:
        response_times = extract_response_times(
            df, const.METRIC_NAME, const.METRIC_VALUE, const.HTTP_REQ_DURATION
        )
        timestamps = extract_response_times(
            df, const.METRIC_NAME, const.TIMESTAP, const.HTTP_REQ_DURATION
        )
        throughput, mean, median = calculate_throughput(timestamps)
        json_troughput_values = np.concatenate([json_troughput_values, throughput])
    protobuf_troughput_values = []
    for df in protobuf_reports[i]:
        response_times = extract_response_times(
            df, const.METRIC_NAME, const.METRIC_VALUE, const.HTTP_REQ_DURATION
        )
        timestamps = extract_response_times(
            df, const.METRIC_NAME, const.TIMESTAP, const.HTTP_REQ_DURATION
        )
        throughput, mean, median = calculate_throughput(timestamps)
        protobuf_troughput_values = np.concatenate(
            [protobuf_troughput_values, throughput]
        )

    print(f"JSON throughput size: {len(json_troughput_values)}")
    print(f"Protobuf throughput size: {len(protobuf_troughput_values)}")

    print("=== Basic Statistics ===")
    print(
        f"JSON: mean = {np.mean(json_troughput_values):.2f}, std = {np.std(json_troughput_values, ddof=1):.2f}"
    )
    print(
        f"Protobuf: mean = {np.mean(protobuf_troughput_values):.2f}, std = {np.std(protobuf_troughput_values, ddof=1):.2f}"
    )

    u_stat, p_value = mannwhitneyu(
        protobuf_troughput_values, json_troughput_values, alternative="two-sided"
    )
    print(f"\n=== Mann-Whitney U Test ===")
    print(f"U statistic = {u_stat}, p-value = {p_value:.4f}")

    probability,diff_samples, pct_diff_ci = bootstrap_probability(
        protobuf_troughput_values, json_troughput_values
    )
    prob_protobuf_better = np.mean(diff_samples)
    diff_ci = np.percentile(diff_samples, [2.5, 97.5])

    print("\n=== Bayesian Estimation Results ===")
    print(f"Probability  Protobuf > JSON: {prob_protobuf_better:.4f}")
    print(f"95% Credible Interval for difference: [{diff_ci[0]:.2f}, {diff_ci[1]:.2f}]")
    print(
        f"95% Credible Interval for % improvement: [{pct_diff_ci[0]:.2f}%, {pct_diff_ci[1]:.2f}%]"
    )

    plt.figure(figsize=(10, 4))
    plt.hist(diff_samples, bins=30, alpha=0.7, density=True)
    plt.axvline(x=0, color="red", linestyle="--", label="No difference")
    plt.axvline(x=diff_ci[0], color="black", linestyle=":", label="95% CI")
    plt.axvline(x=diff_ci[1], color="black", linestyle=":")
    plt.title("Posterior Distribution of Throughput Difference (A - B)")
    plt.xlabel("Difference in Throughput")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    json_median = np.median(json_troughput_values)
    protobuf_median = np.median(protobuf_troughput_values)

    delta, res = cliffs_delta(json_troughput_values, protobuf_troughput_values)

    _, p_median, _, _ = median_test(protobuf_troughput_values, json_troughput_values)

    print(f"JSON Median Throughput: {json_median}")
    print(f"Protobuf Median Throughput: {protobuf_median}")
    print(
        f"Cliff’s Delta: {delta} (Interpretation: Small <0.147, Medium <0.33, Large >0.33)"
    )
    print(f"Median Test p-value: {p_median}")

    plt.figure(figsize=(10, 5))
    sns.kdeplot(json_troughput_values, label="JSON", fill=True)
    sns.kdeplot(protobuf_troughput_values, label="Protobuf", fill=True)
    plt.xlabel("Throughput (req/s)")
    plt.ylabel("Density")
    plt.title(f"Throughput Distribution - {endpoint}")
    plt.legend()
    plt.show()

    json_normality_p = normaltest(json_troughput_values).pvalue
    protobuf_normality_p = normaltest(protobuf_troughput_values).pvalue
    variance_p = levene(protobuf_troughput_values, json_troughput_values).pvalue

    if json_normality_p > 0.05 and protobuf_normality_p > 0.05:
        test_stat, p_value = ttest_ind(
            protobuf_troughput_values,
            json_troughput_values,
            equal_var=(variance_p >= 0.05),
        )
        test_name = "t-test"
    else:
        test_stat, p_value = mannwhitneyu(
            protobuf_troughput_values, json_troughput_values, alternative="greater"
        )
        test_name = "Mann-Whitney U test"

    print(f"Endpoint: {endpoint} ({test_name})")
    print(f"p-value: {p_value}")
    if p_value < 0.05:
        print("Significant difference found!\n")
    else:
        print("No significant difference.\n")
# Out:
# Endpoint: create_user
# JSON throughput size: 1000
# Protobuf throughput size: 1000
# === Basic Statistics ===
# JSON: mean = 10.63, std = 1.09
# Protobuf: mean = 10.72, std = 1.07
#
# === Mann-Whitney U Test ===
# U statistic = 523693.0, p-value = 0.0443
#
# === Bayesian Estimation Results ===
# Probability  Protobuf > JSON: 0.0923
# 95% Credible Interval for difference: [-0.00, 0.19]
# 95% Credible Interval for % improvement: [-0.00%, 0.19%]
# JSON Median Throughput: 11.0
# Protobuf Median Throughput: 11.0
# Cliff’s Delta: -0.047386 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# Median Test p-value: 0.00022012635443351036
# Endpoint: create_user (Mann-Whitney U test)
# p-value: 0.022167978329702433
# Significant difference found!
#
# Endpoint: get_all_users
# JSON throughput size: 1000
# Protobuf throughput size: 1000
# === Basic Statistics ===
# JSON: mean = 172.15, std = 47.68
# Protobuf: mean = 168.80, std = 49.18
#
# === Mann-Whitney U Test ===
# U statistic = 472779.0, p-value = 0.0343
#
# === Bayesian Estimation Results ===
# Probability  Protobuf > JSON: -3.3914
# 95% Credible Interval for difference: [-7.68, 0.87]
# 95% Credible Interval for % improvement: [-7.68%, 0.87%]
# JSON Median Throughput: 179.0
# Protobuf Median Throughput: 170.0
# Cliff’s Delta: 0.054442 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# Median Test p-value: 4.069229748010787e-61
# Endpoint: get_all_users (Mann-Whitney U test)
# p-value: 0.9828431726454704
# No significant difference.
#
# Endpoint: get_user_id
# JSON throughput size: 1000
# Protobuf throughput size: 1000
# === Basic Statistics ===
# JSON: mean = 186.49, std = 53.16
# Protobuf: mean = 200.07, std = 65.34
#
# === Mann-Whitney U Test ===
# U statistic = 594783.0, p-value = 0.0000
#
# === Bayesian Estimation Results ===
# Probability  Protobuf > JSON: 13.5579
# 95% Credible Interval for difference: [8.41, 18.76]
# 95% Credible Interval for % improvement: [8.41%, 18.76%]
# JSON Median Throughput: 172.0
# Protobuf Median Throughput: 186.0
# Cliff’s Delta: -0.189566 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# Median Test p-value: 0.282401723176201
# Endpoint: get_user_id (Mann-Whitney U test)
# p-value: 8.04361289637334e-14
# Significant difference found!
#
# Endpoint: get_all_product_entities
# JSON throughput size: 1000
# Protobuf throughput size: 1000
# === Basic Statistics ===
# JSON: mean = 56.99, std = 22.11
# Protobuf: mean = 60.99, std = 14.36
#
# === Mann-Whitney U Test ===
# U statistic = 588600.5, p-value = 0.0000
#
# === Bayesian Estimation Results ===
# Probability  Protobuf > JSON: 3.9976
# 95% Credible Interval for difference: [2.38, 5.64]
# 95% Credible Interval for % improvement: [2.38%, 5.64%]
# JSON Median Throughput: 51.0
# Protobuf Median Throughput: 63.0
# Cliff’s Delta: -0.177201 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# Median Test p-value: 1.525282989006216e-13
# Endpoint: get_all_product_entities (Mann-Whitney U test)
# p-value: 3.2206487503810925e-12
# Significant difference found!
#
# Endpoint: update_user
# JSON throughput size: 1000
# Protobuf throughput size: 1000
# === Basic Statistics ===
# JSON: mean = 97.42, std = 19.84
# Protobuf: mean = 97.86, std = 15.93
#
# === Mann-Whitney U Test ===
# U statistic = 459450.0, p-value = 0.0016
#
# === Bayesian Estimation Results ===
# Probability  Protobuf > JSON: 0.4364
# 95% Credible Interval for difference: [-1.15, 2.01]
# 95% Credible Interval for % improvement: [-1.15%, 2.01%]
# JSON Median Throughput: 101.0
# Protobuf Median Throughput: 104.0
# Cliff’s Delta: 0.0811 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# Median Test p-value: 0.00034557463176240115
# Endpoint: update_user (Mann-Whitney U test)
# p-value: 0.9991881984673663
# No significant difference.
#
# Endpoint: delete_user
# JSON throughput size: 1000
# Protobuf throughput size: 1000
# === Basic Statistics ===
# JSON: mean = 106.49, std = 22.37
# Protobuf: mean = 116.43, std = 25.31
#
# === Mann-Whitney U Test ===
# U statistic = 667014.5, p-value = 0.0000
#
# === Bayesian Estimation Results ===
# Probability  Protobuf > JSON: 9.9444
# 95% Credible Interval for difference: [7.83, 12.00]
# 95% Credible Interval for % improvement: [7.83%, 12.00%]
# JSON Median Throughput: 110.0
# Protobuf Median Throughput: 130.0
# Cliff’s Delta: -0.334029 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# Median Test p-value: 2.315387270386095e-37
# Endpoint: delete_user (Mann-Whitney U test)
# p-value: 7.802049064326289e-39
# Significant difference found!

# %% [markdown]
# ### Energy Consumption

# %% [markdown]
# #### Global Energy Consumption

# %%
json_median = np.median(json_all_pod_reports)
protobuf_median = np.median(protobuf_all_pod_reports)

json_median_gateway = np.median(json_all_gateway_pod_reports)
protobuf_median_gateway = np.median(protobuf_all_gateway_pod_reports)

delta, res = cliffs_delta(json_all_pod_reports, protobuf_all_pod_reports)

_, p_median, _, _ = median_test(json_all_pod_reports, protobuf_all_pod_reports)

print(f"JSON Median Energy Consumption: {json_median}")
print(f"Protobuf Median Energy Consumption: {protobuf_median}")
print(f"JSON Median Gateway Energy Consumption: {json_median_gateway}")
print(f"Protobuf Median Gateway Energy Consumption: {protobuf_median_gateway}")
print(
    f"Cliff’s Delta: {delta} (Interpretation: Small <0.147, Medium <0.33, Large >0.33)"
)
print(f"Median Test p-value: {p_median}")
# Out:
# JSON Median Energy Consumption: 4.124500000000019
# Protobuf Median Energy Consumption: 4.005199999999968
# JSON Median Gateway Energy Consumption: 1.2492000000000036
# Protobuf Median Gateway Energy Consumption: 1.180799999999984
# Cliff’s Delta: -0.20494417862838915 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# Median Test p-value: 0.28962212322475334

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(json_all_pod_reports, label="JSON", fill=True)
sns.kdeplot(protobuf_all_pod_reports, label="Protobuf", fill=True)
plt.xlabel("Energy Consumption (Watts)")
plt.ylabel("Density")
plt.title("Energy Consumption Distribution")
plt.legend()
plt.show()

# %%
# Normality test
json_normality_p = normaltest(json_all_pod_reports).pvalue
protobuf_normality_p = normaltest(protobuf_all_pod_reports).pvalue

# Variance test
variance_p = levene(json_all_pod_reports, protobuf_all_pod_reports).pvalue

# %%
# Choose the correct statistical test
if json_normality_p > 0.05 and protobuf_normality_p > 0.05:
    test_stat, p_value = ttest_ind(
        json_all_pod_reports,
        protobuf_all_pod_reports,
        equal_var=(variance_p >= 0.05),
    )
    test_name = "t-test"
else:
    test_stat, p_value = mannwhitneyu(
        json_all_pod_reports,
        protobuf_all_pod_reports,
        alternative="two-sided",
    )
    test_name = "Mann-Whitney U test"

print(f"Energy Consumption ({test_name})")
print(f"p-value: {p_value}")
if p_value < 0.05:
    print("Significant difference found!\n")
else:
    print("No significant difference.\n")
# Out:
# Energy Consumption (Mann-Whitney U test)
# p-value: 3.7681820236731896e-07
# Significant difference found!

# %% [markdown]
# #### Per EndPoint Energy Consumption

# %%
## Display Table with data
### Total joules, average joules, median joules,max, min, std, joules per request,


def compute_energy_statistics(
    serialization, endpoint, pod_report_list, is_creation=False,is_debug=False
):
    if is_debug:
        print(f"ENDPOINT: {endpoint} \n")
        print(f"DEBUG POD REPORT LIST: {pod_report_list[0]} \n")
        print(f"{len(pod_report_list)}")
        print(f"{len(pod_report_list[0])}")
        print("END OF DEBUG POD REPORT LIST \n")
    total_requests = 1000 * len(pod_report_list)
    table_dataframe_data = pd.DataFrame(
        columns=[
            "serialization",
            "endpoint",
            "Total Joules",
            "Total Average Joules",
            "Average Joules",
            "Median Joules",
            "maximum Joules",
            "minimum Joules",
            "std",
            "Joules per Request",
        ]
    )
    energy_consumption = np.concatenate(
        [
            extract_energy_consumption(
                df, [const.TOTAL]
            )
            for df in pod_report_list
        ]
    )

    total_average_trial = np.zeros(len(pod_report_list))
    for i in range(len(pod_report_list)):
        total_average_trial[i] = np.sum(
            extract_energy_consumption(
                pod_report_list[i], [const.TOTAL]
            )
        )
    
    

    total_energy_consumption = round(np.sum(energy_consumption), 2)
    total_average_energy_consumption = round(np.mean(total_average_trial), 2)
    average_energy_consumption = round(np.mean(energy_consumption), 2)
    median_energy_consumption = round(np.median(energy_consumption), 2)
    max_energy_consumption = round(np.max(energy_consumption), 2)
    min_energy_consumption = round(np.min(energy_consumption), 2)
    std_energy_consumption = round(np.std(energy_consumption, ddof=1), 2)
    joules_per_request = round(total_energy_consumption / (
        total_requests 
    ),2)

    table_dataframe_data = pd.DataFrame(
        {
            "serialization": [serialization],
            "endpoint": [endpoint],
            "Total Joules": [total_energy_consumption],
            "Total Average Joules": [total_average_energy_consumption],
            "Average Joules": [average_energy_consumption],
            "Median Joules": [median_energy_consumption],
            "maximum Joules": [max_energy_consumption],
            "minimum Joules": [min_energy_consumption],
            "std": [std_energy_consumption],
            "Joules per Request": [joules_per_request],
        }
    )
    return table_dataframe_data, energy_consumption

# %%
JSON = "JSON"
PROTOBUF = "Protobuf"
for i, endpoint in enumerate(endpoints):
    print(f"\n<----------------------------START OF {endpoint} TESTS-------------------------->\n")
    is_creation = True if i == 0 else False

    json_table_energy_consumption,json_energy_consumption = compute_energy_statistics(JSON,endpoint,json_pod_reports[i],is_creation,False)
    protobuf_table_energy_consumption,protobuf_energy_consumption = compute_energy_statistics(PROTOBUF,endpoint,protobuf_pod_reports[i],is_creation,False)

    json_table_energy_comsunption_gateway,json_energy_consumption_gateway = compute_energy_statistics(JSON,endpoint,json_pod_gateway_reports[i],is_creation,False)
    protobuf_table_energy_consumption_gateway,protobuf_energy_consumption_gateway = compute_energy_statistics(PROTOBUF,endpoint,protobuf_pod_gateway_reports[i],is_creation,False)
    

    json_energy_consumption_plus_json_gateway_energy_consumption = np.concatenate([json_energy_consumption,json_energy_consumption_gateway])
    protobuf_energy_consumption_plus_protobuf_gateway_energy_consumption = np.concatenate([protobuf_energy_consumption,protobuf_energy_consumption_gateway])

    json_table_energy_consumption_plus_gateway_energy_consumption, _ = compute_energy_statistics(
        JSON,
        endpoint,
        json_pod_reports[i] + json_pod_gateway_reports[i],
        is_creation,
        False
    )
    protobuf_table_energy_consumption_plus_gateway_energy_consumption, _ = compute_energy_statistics(
        PROTOBUF,
        endpoint,
        protobuf_pod_reports[i] + protobuf_pod_gateway_reports[i],
        is_creation,
        False
    )
    


    print(f"\nENDPOINT ENERGY CONSUMPTION TABLE \n")
    concatenated_table = pd.concat([json_table_energy_consumption,protobuf_table_energy_consumption])
    display(concatenated_table)

    print(f"\nENDPOINT ENERGY CONSUMPTION GATEWAY TABLE \n")
    concatenated_table_gateway = pd.concat([json_table_energy_comsunption_gateway,protobuf_table_energy_consumption_gateway])
    display(concatenated_table_gateway)

    print(f"\nENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE\n")
    concatenated_table_plus_gateway = pd.concat([json_table_energy_consumption_plus_gateway_energy_consumption,protobuf_table_energy_consumption_plus_gateway_energy_consumption])
    display(concatenated_table_plus_gateway)

    print(f"\nENDPOINT ENERGY CONSUMPTION TABLE PERCENTAGE DIFFERENCE \n")
    diff_table = display_percentage_difference_energy(concatenated_table)
    display(diff_table)

    print(f"\nENDPOINT ENERGY CONSUMPTION GATEWAY TABLE PERCENTAGE DIFFERENCE \n")
    diff_table_gateway = display_percentage_difference_energy(concatenated_table_gateway)
    display(diff_table_gateway)
    
    print(f"\nENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE PERCENTAGE DIFFERENCE \n")
    diff_table_plus_gateway = display_percentage_difference_energy(concatenated_table_plus_gateway)
    display(diff_table_plus_gateway)
    

    p,diffs,ci = bootstrap_probability(protobuf_energy_consumption,json_energy_consumption)

    print(f"Probability of Protobuf > JSON: {p}")
    print(f"95% CI for differenc in energy consumption Protobuf > JSON: [{ci[0]:.4f}, {ci[1]:.4f}]")
    
    histogram_plot_data(diffs, "Posterior Distribution of Energy Consumption Difference (Protobuf - JSON)", "Energy Consumption (Joules)")

    # plot a histogram of the energy consumption
    plt.figure(figsize=(10, 5))
    sns.kdeplot(json_energy_consumption, label="JSON", fill=True,warn_singular=False)
    sns.kdeplot(protobuf_energy_consumption, label="Protobuf", fill=True,warn_singular=False)
    plt.xlabel("Energy Consumption (Watts)")
    plt.ylabel("Density")
    plt.title("Energy Consumption Distribution")
    plt.legend()
    plt.show()
    
    
    json_total_energy_consumption = np.sum(json_energy_consumption)
    protobuf_total_energy_consumption = np.sum(protobuf_energy_consumption)
    json_median = np.median(json_energy_consumption)
    protobuf_median = np.median(protobuf_energy_consumption)

    delta, res = cliffs_delta(json_energy_consumption, protobuf_energy_consumption)


    combined_data = np.concatenate((protobuf_energy_consumption, json_energy_consumption))
    grand_median = np.median(combined_data)

    protobuf_below = np.any(protobuf_energy_consumption < grand_median)
    protobuf_above = np.any(protobuf_energy_consumption > grand_median)

    json_below = np.any(json_energy_consumption < grand_median)
    json_above = np.any(json_energy_consumption > grand_median)

    if (protobuf_below and protobuf_above) or (json_below and json_above):
        _, p_median, _, _ = median_test(protobuf_energy_consumption, json_energy_consumption)
        print(f"Median Test p-value: {p_median}")
    else:
        print("Median test not applicable due to all values being on one side of the median.")

    
    print(
        f"Cliff’s Delta: {delta} (Interpretation: Small <0.147, Medium <0.33, Large >0.33)"
    )

    plt.figure(figsize=(10, 5))
    sns.kdeplot(json_energy_consumption , label="JSON", fill=True)
    sns.kdeplot(protobuf_energy_consumption, label="Protobuf", fill=True)
    plt.xlabel("Energy Consumption (Joules)")
    plt.ylabel("Density")
    plt.title(f"Energy Consumption Distribution - {endpoint}")
    plt.legend()
    plt.show()

    json_normality_p = normaltest(json_energy_consumption).pvalue
    protobuf_normality_p = normaltest(protobuf_energy_consumption).pvalue

    variance_p = levene(protobuf_energy_consumption,json_energy_consumption).pvalue

    if json_normality_p > 0.05 and protobuf_normality_p > 0.05:
        test_stat, p_value = ttest_ind(
            protobuf_energy_consumption, json_energy_consumption, equal_var=(variance_p >= 0.05)
        )
        test_name = "t-test"
    else:
        test_stat, p_value = mannwhitneyu(
            protobuf_energy_consumption, json_energy_consumption, alternative="less"
        )
        test_name = "Mann-Whitney U test"

    print(f"p-value: {p_value}")
    if p_value < 0.05:
        print("Significant difference found!\n")
    else:
        print("No significant difference.\n")
        

    print(f"Testing api consumption + gateway energy consumption\n")   
     
    plt.Figure(figsize=(10, 5))
    sns.kdeplot(json_energy_consumption_plus_json_gateway_energy_consumption, label="JSON", fill=True)
    sns.kdeplot(protobuf_energy_consumption_plus_protobuf_gateway_energy_consumption, label="Protobuf", fill=True)
    plt.xlabel("Energy Consumption (Joules)")
    plt.ylabel("Density")
    plt.title(f"Energy Consumption Distribution - {endpoint} + Gateway")
    plt.legend()
    plt.show()
    
    

    json_with_gateway_normality_p = normaltest(json_energy_consumption_plus_json_gateway_energy_consumption).pvalue
    protobuf_with_gateway_normality_p = normaltest(protobuf_energy_consumption_plus_protobuf_gateway_energy_consumption).pvalue

    variance_with_gateway_p = levene(protobuf_energy_consumption_plus_protobuf_gateway_energy_consumption,json_energy_consumption_plus_json_gateway_energy_consumption).pvalue

    if json_with_gateway_normality_p > 0.05 and protobuf_with_gateway_normality_p > 0.05:
        test_stat, p_value = ttest_ind(
            protobuf_energy_consumption_plus_protobuf_gateway_energy_consumption,
            json_energy_consumption_plus_json_gateway_energy_consumption,
            equal_var=(variance_with_gateway_p >= 0.05),
        )
        test_name = "t-test"
    else:
        test_stat, p_value = mannwhitneyu(
            protobuf_energy_consumption_plus_protobuf_gateway_energy_consumption,
            json_energy_consumption_plus_json_gateway_energy_consumption,
            alternative="less",
        )
        test_name = "Mann-Whitney U test"
    print(f"p-value: {p_value}")
    if p_value < 0.05:
        print("Significant difference found!\n")
    else:
        print("No significant difference.\n")
    
    print(f"\n<----------------------------END OF {endpoint} TESTS------------------------------>\n")
# Out:
# <----------------------------START OF create_user TESTS-------------------------->
#
#
# ENDPOINT ENERGY CONSUMPTION TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  create_user        417.69                417.69
# 0      Protobuf  create_user        411.89                411.89
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            4.35           5.44            5.47            1.94  1.63
# 0            4.34           5.53            5.53            2.31  1.46
#
#    Joules per Request
# 0                0.42
# 0                0.41
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  create_user        146.48                146.48
# 0      Protobuf  create_user        140.78                140.78
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            1.53           1.26            4.43            1.25  0.88
# 0            1.48           1.18            3.87            1.15  0.87
#
#    Joules per Request
# 0                0.15
# 0                0.14
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  create_user        564.17                282.08
# 0      Protobuf  create_user        552.67                276.33
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            2.94           1.94            5.47            1.25  1.93
# 0            2.91           2.31            5.53            1.15  1.87
#
#    Joules per Request
# 0                0.28
# 0                0.28
# ENDPOINT ENERGY CONSUMPTION TABLE PERCENTAGE DIFFERENCE
#    Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (1.39, True)         (1.39, True)   (0.23, True)  (1.65, False)
#
#   maximum Joules  minimum Joules            std Joules per Request
# 0   (1.1, False)  (19.07, False)  (10.43, True)       (2.38, True)
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE PERCENTAGE DIFFERENCE
#    Total Joules Total Average Joules Average Joules Median Joules  \
# 0  (3.89, True)         (3.89, True)   (3.27, True)  (6.35, True)
#
#   maximum Joules minimum Joules           std Joules per Request
# 0  (12.64, True)    (8.0, True)  (1.14, True)       (6.67, True)
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE PERCENTAGE DIFFERENCE
#    Total Joules Total Average Joules Average Joules   Median Joules  \
# 0  (2.04, True)         (2.04, True)   (1.02, True)  (19.07, False)
#
#   maximum Joules minimum Joules           std Joules per Request
# 0   (1.1, False)    (8.0, True)  (3.11, True)       (0.0, False)
# Probability of Protobuf > JSON: 0.5284
# 95% CI for differenc in energy consumption Protobuf > JSON: [-0.4486, 0.4292]
# Median Test p-value: 0.0002012979190032134
# Cliff’s Delta: -0.40657894736842104 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# p-value: 0.9999995358283548
# No significant difference.
#
# Testing api consumption + gateway energy consumption
# p-value: 0.05341661121142728
# No significant difference.
#
#
# <----------------------------END OF create_user TESTS------------------------------>
#
#
# <----------------------------START OF get_all_users TESTS-------------------------->
#
#
# ENDPOINT ENERGY CONSUMPTION TABLE
#   serialization       endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_users         15.93                 15.93
# 0      Protobuf  get_all_users         17.52                 17.52
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            2.28           2.28            2.28            2.28  0.0
# 0            2.50           2.50            2.50            2.50  0.0
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE
#   serialization       endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_users         17.86                 17.86
# 0      Protobuf  get_all_users         20.40                 20.40
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            2.55           2.55            2.55            2.55  0.0
# 0            2.91           2.91            2.91            2.91  0.0
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE
#   serialization       endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_users         33.79                 16.90
# 0      Protobuf  get_all_users         37.93                 18.96
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            2.41           2.41            2.55            2.28  0.14
# 0            2.71           2.71            2.91            2.50  0.21
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ENDPOINT ENERGY CONSUMPTION TABLE PERCENTAGE DIFFERENCE
#     Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (9.98, False)        (9.98, False)  (9.65, False)  (9.65, False)
#
#   maximum Joules minimum Joules         std Joules per Request
# 0  (9.65, False)  (9.65, False)  (0, False)       (0.0, False)
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE PERCENTAGE DIFFERENCE
#      Total Joules Total Average Joules  Average Joules   Median Joules  \
# 0  (14.22, False)       (14.22, False)  (14.12, False)  (14.12, False)
#
#    maximum Joules  minimum Joules         std Joules per Request
# 0  (14.12, False)  (14.12, False)  (0, False)       (0.0, False)
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE PERCENTAGE DIFFERENCE
#      Total Joules Total Average Joules  Average Joules   Median Joules  \
# 0  (12.25, False)       (12.19, False)  (12.45, False)  (12.45, False)
#
#    maximum Joules minimum Joules            std Joules per Request
# 0  (14.12, False)  (9.65, False)  (50.0, False)       (0.0, False)
# Probability of Protobuf > JSON: 0.0
# 95% CI for differenc in energy consumption Protobuf > JSON: [0.2276, 0.2276]
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:73: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Median test not applicable due to all values being on one side of the median.
# Cliff’s Delta: -1.0 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:106: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(json_energy_consumption , label="JSON", fill=True)
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:107: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(protobuf_energy_consumption, label="Protobuf", fill=True)
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:111: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# p-value: 0.999882986336028
# No significant difference.
#
# Testing api consumption + gateway energy consumption
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:114: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   json_normality_p = normaltest(json_energy_consumption).pvalue
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:115: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   protobuf_normality_p = normaltest(protobuf_energy_consumption).pvalue
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_morestats.py:3057: RuntimeWarning: invalid value encountered in scalar divide
#   W = numer / denom
# p-value: 0.9905501179769164
# No significant difference.
#
#
# <----------------------------END OF get_all_users TESTS------------------------------>
#
#
# <----------------------------START OF get_user_id TESTS-------------------------->
#
#
# ENDPOINT ENERGY CONSUMPTION TABLE
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=14 observations were given.
#   return hypotest_fun_in(*args, **kwds)
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_user_id         24.81                 24.81
# 0      Protobuf  get_user_id         25.58                 25.58
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            3.54           3.54            3.54            3.54  0.00
# 0            3.65           4.49            4.49            1.58  1.42
#
#    Joules per Request
# 0                0.02
# 0                0.03
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_user_id         22.22                 22.22
# 0      Protobuf  get_user_id         23.74                 23.74
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            3.17           3.17            3.17            3.17  0.00
# 0            3.39           4.21            4.21            1.35  1.39
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_user_id         47.03                 23.52
# 0      Protobuf  get_user_id         49.32                 24.66
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            3.36           3.36            3.54            3.17  0.19
# 0            3.52           4.21            4.49            1.35  1.36
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ENDPOINT ENERGY CONSUMPTION TABLE PERCENTAGE DIFFERENCE
#    Total Joules Total Average Joules Average Joules   Median Joules  \
# 0  (3.1, False)         (3.1, False)  (3.11, False)  (26.84, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (26.84, False)  (55.37, True)  (0, False)      (50.0, False)
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE PERCENTAGE DIFFERENCE
#     Total Joules Total Average Joules Average Joules   Median Joules  \
# 0  (6.84, False)        (6.84, False)  (6.94, False)  (32.81, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (32.81, False)  (57.41, True)  (0, False)       (0.0, False)
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE PERCENTAGE DIFFERENCE
#     Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (4.87, False)        (4.85, False)  (4.76, False)  (25.3, False)
#
#    maximum Joules minimum Joules              std Joules per Request
# 0  (26.84, False)  (57.41, True)  (615.79, False)       (0.0, False)
# Probability of Protobuf > JSON: 0.317
# 95% CI for differenc in energy consumption Protobuf > JSON: [-0.7217, 0.9413]
# Median Test p-value: 0.025674942578765007
# Cliff’s Delta: -0.42857142857142855 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:106: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(json_energy_consumption , label="JSON", fill=True)
# p-value: 0.9384697014460687
# No significant difference.
#
# Testing api consumption + gateway energy consumption
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:114: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   json_normality_p = normaltest(json_energy_consumption).pvalue
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:115: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   protobuf_normality_p = normaltest(protobuf_energy_consumption).pvalue
# p-value: 0.9769935541878005
# No significant difference.
#
#
# <----------------------------END OF get_user_id TESTS------------------------------>
#
#
# <----------------------------START OF get_all_product_entities TESTS-------------------------->
#
#
# ENDPOINT ENERGY CONSUMPTION TABLE
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=14 observations were given.
#   return hypotest_fun_in(*args, **kwds)
#   serialization                  endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_product_entities         22.34                 22.34
# 0      Protobuf  get_all_product_entities         20.06                 20.06
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            1.02           1.02            1.02            1.02  0.00
# 0            1.11           1.11            1.14            1.11  0.01
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE
#   serialization                  endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_product_entities         21.98                 21.98
# 0      Protobuf  get_all_product_entities         32.56                 32.56
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            1.00           1.00            1.00            1.00  0.00
# 0            1.81           1.57            3.76            1.57  0.71
#
#    Joules per Request
# 0                0.02
# 0                0.03
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE
#   serialization                  endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_product_entities         44.32                 22.16
# 0      Protobuf  get_all_product_entities         52.62                 26.31
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            1.01           1.01            1.02            1.00  0.01
# 0            1.46           1.35            3.76            1.11  0.61
#
#    Joules per Request
# 0                0.02
# 0                0.03
# ENDPOINT ENERGY CONSUMPTION TABLE PERCENTAGE DIFFERENCE
#     Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (10.21, True)        (10.21, True)  (8.82, False)  (8.82, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (11.76, False)  (8.82, False)  (0, False)       (0.0, False)
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE PERCENTAGE DIFFERENCE
#      Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (48.13, False)       (48.13, False)  (81.0, False)  (57.0, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (276.0, False)  (57.0, False)  (0, False)      (50.0, False)
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE PERCENTAGE DIFFERENCE
#      Total Joules Total Average Joules  Average Joules   Median Joules  \
# 0  (18.73, False)       (18.73, False)  (44.55, False)  (33.66, False)
#
#     maximum Joules minimum Joules              std Joules per Request
# 0  (268.63, False)  (11.0, False)  (6000.0, False)      (50.0, False)
# Probability of Protobuf > JSON: 0.0
# 95% CI for differenc in energy consumption Protobuf > JSON: [0.0959, 0.1040]
# Median test not applicable due to all values being on one side of the median.
# Cliff’s Delta: -1.0 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:106: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(json_energy_consumption , label="JSON", fill=True)
# p-value: 0.9999999996124616
# No significant difference.
#
# Testing api consumption + gateway energy consumption
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1636: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis, _no_deco=True)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1748: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False, _no_deco=True)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=18 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# p-value: 0.9999999999999986
# No significant difference.
#
#
# <----------------------------END OF get_all_product_entities TESTS------------------------------>
#
#
# <----------------------------START OF update_user TESTS-------------------------->
#
#
# ENDPOINT ENERGY CONSUMPTION TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  update_user         32.64                 32.64
# 0      Protobuf  update_user         44.06                 44.06
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            2.97           2.97            2.97            2.97  0.0
# 0            4.01           4.01            4.01            4.01  0.0
#
#    Joules per Request
# 0                0.03
# 0                0.04
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  update_user         10.70                 10.70
# 0      Protobuf  update_user         10.91                 10.91
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            0.97           0.97            0.97            0.97  0.0
# 0            0.99           0.99            0.99            0.99  0.0
#
#    Joules per Request
# 0                0.01
# 0                0.01
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  update_user         43.34                 21.67
# 0      Protobuf  update_user         54.97                 27.48
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            1.97           1.97            2.97            0.97  1.02
# 0            2.50           2.50            4.01            0.99  1.54
#
#    Joules per Request
# 0                0.02
# 0                0.03
# ENDPOINT ENERGY CONSUMPTION TABLE PERCENTAGE DIFFERENCE
#      Total Joules Total Average Joules  Average Joules   Median Joules  \
# 0  (34.99, False)       (34.99, False)  (35.02, False)  (35.02, False)
#
#    maximum Joules  minimum Joules         std Joules per Request
# 0  (35.02, False)  (35.02, False)  (0, False)     (33.33, False)
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE PERCENTAGE DIFFERENCE
#     Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (1.96, False)        (1.96, False)  (2.06, False)  (2.06, False)
#
#   maximum Joules minimum Joules         std Joules per Request
# 0  (2.06, False)  (2.06, False)  (0, False)       (0.0, False)
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE PERCENTAGE DIFFERENCE
#      Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (26.83, False)       (26.81, False)  (26.9, False)  (26.9, False)
#
#    maximum Joules minimum Joules             std Joules per Request
# 0  (35.02, False)  (2.06, False)  (50.98, False)      (50.0, False)
# Probability of Protobuf > JSON: 0.0
# 95% CI for differenc in energy consumption Protobuf > JSON: [1.0375, 1.0375]
# Median test not applicable due to all values being on one side of the median.
# Cliff’s Delta: -1.0 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:106: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(json_energy_consumption , label="JSON", fill=True)
# p-value: 0.9999980854404961
# No significant difference.
#
# Testing api consumption + gateway energy consumption
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1636: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis, _no_deco=True)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=11 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1748: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False, _no_deco=True)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_morestats.py:3057: RuntimeWarning: invalid value encountered in scalar divide
#   W = numer / denom
# p-value: 0.998383627601229
# No significant difference.
#
#
# <----------------------------END OF update_user TESTS------------------------------>
#
#
# <----------------------------START OF delete_user TESTS-------------------------->
#
#
# ENDPOINT ENERGY CONSUMPTION TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  delete_user         41.25                 41.25
# 0      Protobuf  delete_user         43.08                 43.08
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            4.12           4.12            4.12            4.12  0.00
# 0            4.31           6.10            6.10            1.62  2.31
#
#    Joules per Request
# 0                0.04
# 0                0.04
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  delete_user         17.33                 17.33
# 0      Protobuf  delete_user         18.27                 18.27
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            1.73           1.73            1.73            1.73  0.00
# 0            1.83           2.28            2.28            1.15  0.58
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  delete_user         58.57                 29.29
# 0      Protobuf  delete_user         61.35                 30.68
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            2.93           2.93            4.12            1.73  1.23
# 0            3.07           2.28            6.10            1.15  2.08
#
#    Joules per Request
# 0                0.03
# 0                0.03
# ENDPOINT ENERGY CONSUMPTION TABLE PERCENTAGE DIFFERENCE
#     Total Joules Total Average Joules Average Joules   Median Joules  \
# 0  (4.44, False)        (4.44, False)  (4.61, False)  (48.06, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (48.06, False)  (60.68, True)  (0, False)       (0.0, False)
# ENDPOINT ENERGY CONSUMPTION GATEWAY TABLE PERCENTAGE DIFFERENCE
#     Total Joules Total Average Joules Average Joules   Median Joules  \
# 0  (5.42, False)        (5.42, False)  (5.78, False)  (31.79, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (31.79, False)  (33.53, True)  (0, False)       (0.0, False)
# ENDPOINT ENERGY CONSUMPTION TABLE + GATEWAY TABLE PERCENTAGE DIFFERENCE
#     Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (4.75, False)        (4.75, False)  (4.78, False)  (22.18, True)
#
#    maximum Joules minimum Joules             std Joules per Request
# 0  (48.06, False)  (33.53, True)  (69.11, False)       (0.0, False)
# Probability of Protobuf > JSON: 0.3633
# 95% CI for differenc in energy consumption Protobuf > JSON: [-1.1605, 1.5284]
# Median Test p-value: 0.014697421770023516
# Cliff’s Delta: -0.2 (Interpretation: Small <0.147, Medium <0.33, Large >0.33)
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\3127452535.py:106: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(json_energy_consumption , label="JSON", fill=True)
# p-value: 0.8064647415467513
# No significant difference.
#
# Testing api consumption + gateway energy consumption
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1636: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis, _no_deco=True)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=10 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1748: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False, _no_deco=True)
# p-value: 0.29522451968513197
# No significant difference.
#
#
# <----------------------------END OF delete_user TESTS------------------------------>

# %%
def foreach_energy_comparison_display_table(
    json_report, protobuf_report, title, endpoint, compute_func, debug=False
):
    for i in range(len(json_report)):

        json_table_energy_consumption, _ = compute_energy_statistics(
            JSON, endpoint, [json_report[i]], is_creation, debug
        )

        protobuf_table_energy_consumption, _ = compute_energy_statistics(
            PROTOBUF, endpoint, [protobuf_report[i]], is_creation, debug
        )

        display_tables(

            [

                [json_table_energy_consumption, protobuf_table_energy_consumption],

            ],

            [

                f"{title}",

            ],
            compute_func,

            True,

        )



JSON = "JSON"

PROTOBUF = "Protobuf"

for i, endpoint in enumerate(endpoints):

    print(
        f"\n<----------------------------START OF {endpoint} TESTS-------------------------->\n"
    )

    is_creation = True if i == 0 else False


    # Join energy consumption of api with gateway for each iteration

    json_gateway_plus_api_energy_consumption = []

    protobuf_gateway_plus_api_energy_consumption = []
    for x in range(len(json_pod_reports[i])):
        json_gateway_plus_api_energy_consumption.append(json_pod_reports[i][x] + json_pod_gateway_reports[i][x])
        protobuf_gateway_plus_api_energy_consumption.append(protobuf_pod_reports[i][x] + protobuf_pod_gateway_reports[i][x])

    foreach_energy_comparison_display_table(
        json_pod_reports[i],
        protobuf_pod_reports[i],
        f"Endpoint {endpoint} Energy Consumption",
        endpoint,
        display_percentage_difference_energy,
        False,
    )

    foreach_energy_comparison_display_table(
        json_pod_gateway_reports[i],
        protobuf_pod_gateway_reports[i],
        f"Endpoint {endpoint} Energy Consumption of Gateway",
        endpoint,
        display_percentage_difference_energy,
        False,
    )

    foreach_energy_comparison_display_table(
        json_gateway_plus_api_energy_consumption,
        protobuf_gateway_plus_api_energy_consumption,
        f"Endpoint {endpoint} Energy Consumption + Gateway",
        endpoint,
        display_percentage_difference_energy,
        False
    )


    ## Print Meta Analysis


    # display_tables(

    #     [

    #         [json_table_energy_consumption, protobuf_table_energy_consumption],

    #         [json_table_energy_comsunption_gateway, protobuf_table_energy_consumption_gateway],

    #         [json_table_energy_consumption_plus_gateway_energy_consumption, protobuf_table_energy_consumption_plus_gateway_energy_consumption]

    #     ],

    #     [

    #         f"Endpoint {endpoint} Energy Consumption",

    #         f"Endpoint {endpoint} Energy Consumption of Gateway",

    #         f"Endpoint {endpoint} Energy Consumption + Gateway"

    #     ],True

    # )


    # print_meta_analysis(

    #     [

    #         json_energy_consumption,

    #         protobuf_energy_consumption,

    #         json_energy_consumption_gateway,

    #         protobuf_energy_consumption_gateway,

    #         json_energy_consumption_plus_json_gateway_energy_consumption,

    #         protobuf_energy_consumption_plus_protobuf_gateway_energy_consumption

    #     ],

    #     [

    #         f"JSON Energy Consumption",

    #         f"Protobuf Energy Consumption",

    #         f"JSON Gateway Energy Consumption",

    #         f"Protobuf Gateway Energy Consumption",

    #         f"JSON Energy Consumption + Gateway",

    #         f"Protobuf Energy Consumption + Gateway"

    #     ],True

    # )


    # plt.Figure(figsize=(10, 5))

    # sns.kdeplot(json_energy_consumption_plus_json_gateway_energy_consumption, label="JSON", fill=True)

    # sns.kdeplot(protobuf_energy_consumption_plus_protobuf_gateway_energy_consumption, label="Protobuf", fill=True)

    # plt.xlabel("Energy Consumption (Joules)")

    # plt.ylabel("Density")

    # plt.title(f"Energy Consumption Distribution - {endpoint} + Gateway")

    # plt.legend()

    # plt.show()


    extracted_json_energy_consumption = np.concatenate(

        [extract_energy_consumption(df, [const.TOTAL]) for df in json_pod_reports[i]]

    )

    extracted_protobuf_energy_consumption = np.concatenate(

        [

            extract_energy_consumption(df, [const.TOTAL])

            for df in protobuf_pod_reports[i]

        ]

    )

    summed_json_energy_consumption_plus_gateway = np.concatenate(

        [

            extract_energy_consumption(df, [const.TOTAL])

            for df in json_pod_reports[i] + json_pod_gateway_reports[i]

        ]

    )

    summed_protobuf_energy_consumption_plus_gateway = np.concatenate(

        [

            extract_energy_consumption(df, [const.TOTAL])

            for df in protobuf_pod_reports[i] + protobuf_pod_gateway_reports[i]

        ]

    )


    pod_results = compare_iterations(
        extracted_protobuf_energy_consumption, extracted_json_energy_consumption
    )

    gateway_results = compare_iterations(
        summed_protobuf_energy_consumption_plus_gateway,
        summed_json_energy_consumption_plus_gateway,
    )


    print("POD COMPARISON:")

    print(f"Endpoint: {pod_results}")

    print(f"Test Name: {pod_results['test_used']}")

    print(f"p-value: {pod_results['p_value']}")

    print(f"JSON Median: {pod_results['json_median']}")

    print(f"Protobuf Median: {pod_results['protobuf_median']}")

    print(f"Interpretation: {pod_results['is_significant']}")


    print("\nGATEWAY COMPARISON:")

    print(f"Endpoint: {gateway_results}")

    print(f"Test Name: {gateway_results['test_used']}")

    print(f"p-value: {gateway_results['p_value']}")

    print(f"JSON Median: {gateway_results['json_median']}")

    print(f"Protobuf Median: {gateway_results['protobuf_median']}")

    print(f"Interpretation: {gateway_results['is_significant']}")


    print(
        f"\n<----------------------------END OF {endpoint} TESTS------------------------------>\n"
    )
# Out:
# <----------------------------START OF create_user TESTS-------------------------->
# ## Endpoint create_user Energy Consumption
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  create_user        417.69                417.69
# 0      Protobuf  create_user        411.89                411.89
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            4.35           5.44            5.47            1.94  1.63
# 0            4.34           5.53            5.53            2.31  1.46
#
#    Joules per Request
# 0                0.42
# 0                0.41
# ## Endpoint create_user Energy Consumption Percentage Difference
#    Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (1.39, True)         (1.39, True)   (0.23, True)  (1.65, False)
#
#   maximum Joules  minimum Joules            std Joules per Request
# 0   (1.1, False)  (19.07, False)  (10.43, True)       (2.38, True)
# ## Endpoint create_user Energy Consumption of Gateway
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  create_user        146.48                146.48
# 0      Protobuf  create_user        140.78                140.78
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            1.53           1.26            4.43            1.25  0.88
# 0            1.48           1.18            3.87            1.15  0.87
#
#    Joules per Request
# 0                0.15
# 0                0.14
# ## Endpoint create_user Energy Consumption of Gateway Percentage Difference
#    Total Joules Total Average Joules Average Joules Median Joules  \
# 0  (3.89, True)         (3.89, True)   (3.27, True)  (6.35, True)
#
#   maximum Joules minimum Joules           std Joules per Request
# 0  (12.64, True)    (8.0, True)  (1.14, True)       (6.67, True)
# ## Endpoint create_user Energy Consumption + Gateway
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  create_user        564.17                564.17
# 0      Protobuf  create_user        552.67                552.67
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            5.88           6.69            9.82            3.21  2.00
# 0            5.82           6.71            7.86            3.46  1.65
#
#    Joules per Request
# 0                0.56
# 0                0.55
# ## Endpoint create_user Energy Consumption + Gateway Percentage Difference
#    Total Joules Total Average Joules Average Joules Median Joules  \
# 0  (2.04, True)         (2.04, True)   (1.02, True)  (0.3, False)
#
#   maximum Joules minimum Joules           std Joules per Request
# 0  (19.96, True)  (7.79, False)  (17.5, True)       (1.79, True)
# POD COMPARISON:
# Endpoint: {'p_value': np.float64(0.9999995358283548), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(5.437800000000008), 'protobuf_median': np.float64(5.52859999999999), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.9999995358283548
# JSON Median: 5.437800000000008
# Protobuf Median: 5.52859999999999
# Interpretation: The difference is not significant
#
# GATEWAY COMPARISON:
# Endpoint: {'p_value': np.float64(0.05341661121142728), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(1.9442000000000008), 'protobuf_median': np.float64(2.3095999999999925), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.05341661121142728
# JSON Median: 1.9442000000000008
# Protobuf Median: 2.3095999999999925
# Interpretation: The difference is not significant
#
# <----------------------------END OF create_user TESTS------------------------------>
#
#
# <----------------------------START OF get_all_users TESTS-------------------------->
# ## Endpoint get_all_users Energy Consumption
#   serialization       endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_users         15.93                 15.93
# 0      Protobuf  get_all_users         17.52                 17.52
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            2.28           2.28            2.28            2.28  0.0
# 0            2.50           2.50            2.50            2.50  0.0
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ## Endpoint get_all_users Energy Consumption Percentage Difference
#     Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (9.98, False)        (9.98, False)  (9.65, False)  (9.65, False)
#
#   maximum Joules minimum Joules         std Joules per Request
# 0  (9.65, False)  (9.65, False)  (0, False)       (0.0, False)
# ## Endpoint get_all_users Energy Consumption of Gateway
#   serialization       endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_users         17.86                 17.86
# 0      Protobuf  get_all_users         20.40                 20.40
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            2.55           2.55            2.55            2.55  0.0
# 0            2.91           2.91            2.91            2.91  0.0
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ## Endpoint get_all_users Energy Consumption of Gateway Percentage Difference
#      Total Joules Total Average Joules  Average Joules   Median Joules  \
# 0  (14.22, False)       (14.22, False)  (14.12, False)  (14.12, False)
#
#    maximum Joules  minimum Joules         std Joules per Request
# 0  (14.12, False)  (14.12, False)  (0, False)       (0.0, False)
# ## Endpoint get_all_users Energy Consumption + Gateway
#   serialization       endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_users         33.79                 33.79
# 0      Protobuf  get_all_users         37.93                 37.93
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            4.83           4.83            4.83            4.83  0.0
# 0            5.42           5.42            5.42            5.42  0.0
#
#    Joules per Request
# 0                0.03
# 0                0.04
# ## Endpoint get_all_users Energy Consumption + Gateway Percentage Difference
#      Total Joules Total Average Joules  Average Joules   Median Joules  \
# 0  (12.25, False)       (12.25, False)  (12.22, False)  (12.22, False)
#
#    maximum Joules  minimum Joules         std Joules per Request
# 0  (12.22, False)  (12.22, False)  (0, False)     (33.33, False)
# POD COMPARISON:
# Endpoint: {'p_value': np.float64(0.999882986336028), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(2.275700000000006), 'protobuf_median': np.float64(2.5033000000000056), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.999882986336028
# JSON Median: 2.275700000000006
# Protobuf Median: 2.5033000000000056
# Interpretation: The difference is not significant
#
# GATEWAY COMPARISON:
# Endpoint: {'p_value': np.float64(0.9905501179769164), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(2.4137000000000057), 'protobuf_median': np.float64(2.709050000000002), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.9905501179769164
# JSON Median: 2.4137000000000057
# Protobuf Median: 2.709050000000002
# Interpretation: The difference is not significant
#
# <----------------------------END OF get_all_users TESTS------------------------------>
#
#
# <----------------------------START OF get_user_id TESTS-------------------------->
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\2457138770.py:133: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   json_norm_p = normaltest(json_data).pvalue
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\2457138770.py:134: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   proto_norm_p = normaltest(protobuf_data).pvalue
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_morestats.py:3057: RuntimeWarning: invalid value encountered in scalar divide
#   W = numer / denom
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=14 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# ## Endpoint get_user_id Energy Consumption
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_user_id         24.81                 24.81
# 0      Protobuf  get_user_id         25.58                 25.58
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            3.54           3.54            3.54            3.54  0.00
# 0            3.65           4.49            4.49            1.58  1.42
#
#    Joules per Request
# 0                0.02
# 0                0.03
# ## Endpoint get_user_id Energy Consumption Percentage Difference
#    Total Joules Total Average Joules Average Joules   Median Joules  \
# 0  (3.1, False)         (3.1, False)  (3.11, False)  (26.84, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (26.84, False)  (55.37, True)  (0, False)      (50.0, False)
# ## Endpoint get_user_id Energy Consumption of Gateway
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_user_id         22.22                 22.22
# 0      Protobuf  get_user_id         23.74                 23.74
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            3.17           3.17            3.17            3.17  0.00
# 0            3.39           4.21            4.21            1.35  1.39
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ## Endpoint get_user_id Energy Consumption of Gateway Percentage Difference
#     Total Joules Total Average Joules Average Joules   Median Joules  \
# 0  (6.84, False)        (6.84, False)  (6.94, False)  (32.81, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (32.81, False)  (57.41, True)  (0, False)       (0.0, False)
# ## Endpoint get_user_id Energy Consumption + Gateway
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_user_id         47.03                 47.03
# 0      Protobuf  get_user_id         49.32                 49.32
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            6.72           6.72            6.72            6.72  0.00
# 0            7.05           8.69            8.69            2.93  2.81
#
#    Joules per Request
# 0                0.05
# 0                0.05
# ## Endpoint get_user_id Energy Consumption + Gateway Percentage Difference
#     Total Joules Total Average Joules Average Joules   Median Joules  \
# 0  (4.87, False)        (4.87, False)  (4.91, False)  (29.32, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (29.32, False)   (56.4, True)  (0, False)       (0.0, False)
# POD COMPARISON:
# Endpoint: {'p_value': np.float64(0.9384697014460687), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(3.5448999999999997), 'protobuf_median': np.float64(4.486199999999997), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.9384697014460687
# JSON Median: 3.5448999999999997
# Protobuf Median: 4.486199999999997
# Interpretation: The difference is not significant
#
# GATEWAY COMPARISON:
# Endpoint: {'p_value': np.float64(0.9769935541878005), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(3.3593), 'protobuf_median': np.float64(4.205699999999994), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.9769935541878005
# JSON Median: 3.3593
# Protobuf Median: 4.205699999999994
# Interpretation: The difference is not significant
#
# <----------------------------END OF get_user_id TESTS------------------------------>
#
#
# <----------------------------START OF get_all_product_entities TESTS-------------------------->
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\2457138770.py:133: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   json_norm_p = normaltest(json_data).pvalue
# C:\Users\migue\AppData\Local\Temp\ipykernel_32024\2457138770.py:134: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   proto_norm_p = normaltest(protobuf_data).pvalue
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=14 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# ## Endpoint get_all_product_entities Energy Consumption
#   serialization                  endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_product_entities         22.34                 22.34
# 0      Protobuf  get_all_product_entities         20.06                 20.06
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            1.02           1.02            1.02            1.02  0.00
# 0            1.11           1.11            1.14            1.11  0.01
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ## Endpoint get_all_product_entities Energy Consumption Percentage Difference
#     Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (10.21, True)        (10.21, True)  (8.82, False)  (8.82, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (11.76, False)  (8.82, False)  (0, False)       (0.0, False)
# ## Endpoint get_all_product_entities Energy Consumption of Gateway
#   serialization                  endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_product_entities         21.98                 21.98
# 0      Protobuf  get_all_product_entities         32.56                 32.56
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            1.00           1.00            1.00            1.00  0.00
# 0            1.81           1.57            3.76            1.57  0.71
#
#    Joules per Request
# 0                0.02
# 0                0.03
# ## Endpoint get_all_product_entities Energy Consumption of Gateway Percentage Difference
#      Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (48.13, False)       (48.13, False)  (81.0, False)  (57.0, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (276.0, False)  (57.0, False)  (0, False)      (50.0, False)
# ## Endpoint get_all_product_entities Energy Consumption + Gateway
#   serialization                  endpoint  Total Joules  Total Average Joules  \
# 0          JSON  get_all_product_entities         44.32                 44.32
# 0      Protobuf  get_all_product_entities         52.62                 52.62
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            2.01           2.01            2.01            2.01  0.00
# 0            2.92           2.68            4.90            2.68  0.72
#
#    Joules per Request
# 0                0.04
# 0                0.05
# ## Endpoint get_all_product_entities Energy Consumption + Gateway Percentage Difference
#      Total Joules Total Average Joules  Average Joules   Median Joules  \
# 0  (18.73, False)       (18.73, False)  (45.27, False)  (33.33, False)
#
#     maximum Joules  minimum Joules         std Joules per Request
# 0  (143.78, False)  (33.33, False)  (0, False)      (25.0, False)
# POD COMPARISON:
# Endpoint: {'p_value': np.float64(0.9999999996124616), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(1.0153), 'protobuf_median': np.float64(1.1111999999999966), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.9999999996124616
# JSON Median: 1.0153
# Protobuf Median: 1.1111999999999966
# Interpretation: The difference is not significant
#
# GATEWAY COMPARISON:
# Endpoint: {'p_value': np.float64(0.9999999999999986), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(1.0072000000000003), 'protobuf_median': np.float64(1.3527499999999977), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.9999999999999986
# JSON Median: 1.0072000000000003
# Protobuf Median: 1.3527499999999977
# Interpretation: The difference is not significant
#
# <----------------------------END OF get_all_product_entities TESTS------------------------------>
#
#
# <----------------------------START OF update_user TESTS-------------------------->
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1636: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis, _no_deco=True)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1748: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False, _no_deco=True)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=18 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# ## Endpoint update_user Energy Consumption
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  update_user         32.64                 32.64
# 0      Protobuf  update_user         44.06                 44.06
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            2.97           2.97            2.97            2.97  0.0
# 0            4.01           4.01            4.01            4.01  0.0
#
#    Joules per Request
# 0                0.03
# 0                0.04
# ## Endpoint update_user Energy Consumption Percentage Difference
#      Total Joules Total Average Joules  Average Joules   Median Joules  \
# 0  (34.99, False)       (34.99, False)  (35.02, False)  (35.02, False)
#
#    maximum Joules  minimum Joules         std Joules per Request
# 0  (35.02, False)  (35.02, False)  (0, False)     (33.33, False)
# ## Endpoint update_user Energy Consumption of Gateway
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  update_user         10.70                 10.70
# 0      Protobuf  update_user         10.91                 10.91
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            0.97           0.97            0.97            0.97  0.0
# 0            0.99           0.99            0.99            0.99  0.0
#
#    Joules per Request
# 0                0.01
# 0                0.01
# ## Endpoint update_user Energy Consumption of Gateway Percentage Difference
#     Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (1.96, False)        (1.96, False)  (2.06, False)  (2.06, False)
#
#   maximum Joules minimum Joules         std Joules per Request
# 0  (2.06, False)  (2.06, False)  (0, False)       (0.0, False)
# ## Endpoint update_user Energy Consumption + Gateway
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  update_user         43.34                 43.34
# 0      Protobuf  update_user         54.97                 54.97
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            3.94           3.94            3.94            3.94  0.0
# 0            5.00           5.00            5.00            5.00  0.0
#
#    Joules per Request
# 0                0.04
# 0                0.05
# ## Endpoint update_user Energy Consumption + Gateway Percentage Difference
#      Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (26.83, False)       (26.83, False)  (26.9, False)  (26.9, False)
#
#   maximum Joules minimum Joules         std Joules per Request
# 0  (26.9, False)  (26.9, False)  (0, False)      (25.0, False)
# POD COMPARISON:
# Endpoint: {'p_value': np.float64(0.9999980854404961), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(2.9677000000000286), 'protobuf_median': np.float64(4.005199999999968), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.9999980854404961
# JSON Median: 2.9677000000000286
# Protobuf Median: 4.005199999999968
# Interpretation: The difference is not significant
#
# GATEWAY COMPARISON:
# Endpoint: {'p_value': np.float64(0.998383627601229), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(1.9700000000000273), 'protobuf_median': np.float64(2.4985499999999927), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.998383627601229
# JSON Median: 1.9700000000000273
# Protobuf Median: 2.4985499999999927
# Interpretation: The difference is not significant
#
# <----------------------------END OF update_user TESTS------------------------------>
#
#
# <----------------------------START OF delete_user TESTS-------------------------->
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1636: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis, _no_deco=True)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=11 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1748: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False, _no_deco=True)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_morestats.py:3057: RuntimeWarning: invalid value encountered in scalar divide
#   W = numer / denom
# ## Endpoint delete_user Energy Consumption
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  delete_user         41.25                 41.25
# 0      Protobuf  delete_user         43.08                 43.08
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            4.12           4.12            4.12            4.12  0.00
# 0            4.31           6.10            6.10            1.62  2.31
#
#    Joules per Request
# 0                0.04
# 0                0.04
# ## Endpoint delete_user Energy Consumption Percentage Difference
#     Total Joules Total Average Joules Average Joules   Median Joules  \
# 0  (4.44, False)        (4.44, False)  (4.61, False)  (48.06, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (48.06, False)  (60.68, True)  (0, False)       (0.0, False)
# ## Endpoint delete_user Energy Consumption of Gateway
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  delete_user         17.33                 17.33
# 0      Protobuf  delete_user         18.27                 18.27
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules   std  \
# 0            1.73           1.73            1.73            1.73  0.00
# 0            1.83           2.28            2.28            1.15  0.58
#
#    Joules per Request
# 0                0.02
# 0                0.02
# ## Endpoint delete_user Energy Consumption of Gateway Percentage Difference
#     Total Joules Total Average Joules Average Joules   Median Joules  \
# 0  (5.42, False)        (5.42, False)  (5.78, False)  (31.79, False)
#
#    maximum Joules minimum Joules         std Joules per Request
# 0  (31.79, False)  (33.53, True)  (0, False)       (0.0, False)
# ## Endpoint delete_user Energy Consumption + Gateway
#   serialization     endpoint  Total Joules  Total Average Joules  \
# 0          JSON  delete_user         58.57                 58.57
# 0      Protobuf  delete_user         61.35                 61.35
#
#    Average Joules  Median Joules  maximum Joules  minimum Joules  std  \
# 0            5.86           5.86            5.86            5.86  0.0
# 0            6.14           8.38            8.38            2.77  2.9
#
#    Joules per Request
# 0                0.06
# 0                0.06
# ## Endpoint delete_user Energy Consumption + Gateway Percentage Difference
#     Total Joules Total Average Joules Average Joules  Median Joules  \
# 0  (4.75, False)        (4.75, False)  (4.78, False)  (43.0, False)
#
#   maximum Joules minimum Joules         std Joules per Request
# 0  (43.0, False)  (52.73, True)  (0, False)       (0.0, False)
# POD COMPARISON:
# Endpoint: {'p_value': np.float64(0.8064647415467513), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(4.124500000000019), 'protobuf_median': np.float64(6.1009999999999), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.8064647415467513
# JSON Median: 4.124500000000019
# Protobuf Median: 6.1009999999999
# Interpretation: The difference is not significant
#
# GATEWAY COMPARISON:
# Endpoint: {'p_value': np.float64(0.29522451968513197), 'test_used': 'Mann-Whitney U', 'json_median': np.float64(2.928699999999999), 'protobuf_median': np.float64(2.279299999999997), 'is_significant': 'The difference is not significant'}
# Test Name: Mann-Whitney U
# p-value: 0.29522451968513197
# JSON Median: 2.928699999999999
# Protobuf Median: 2.279299999999997
# Interpretation: The difference is not significant
#
# <----------------------------END OF delete_user TESTS------------------------------>
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1636: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis, _no_deco=True)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=10 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# c:\Users\migue\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1748: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = kurtosis(a, axis, fisher=False, _no_deco=True)
